# %%
import os
import json

from dotenv import load_dotenv
load_dotenv()

import pandas as pd
import numpy as np

med_qa_data = pd.read_csv('data/cleaned_MedQA_complete_graded_data_encoded.csv')

# %%
med_qa_data.head()
# Out:
#                                             question  \
# 0  Two weeks after undergoing an emergency cardia...
# 1  A 46-year-old man is brought to the emergency ...
# 2  A 30-year-old African American woman comes to ...
# 3  A 67-year-old man who was diagnosed with arthr...
# 4  A one-day-old male is evaluated in the hospita...
#
#                              answer                      new_IR IR Grade  \
# 0          Cholesterol embolization  Thrombotic microangiopathy        N
# 1       Benzodiazepine intoxication        Alcohol intoxication        N
# 2  Histoplasma capsulatum infection                Valley Fever        N
# 3               Psoriatic arthritis         Psoriatic arthritis        Y
# 4                  Duodenal atresia               Gastroschisis        N
#
#                         new_AR AR Grade                       new_BR BR Grade  \
# 0  Thrombotic microangiopathy.        N  Thrombotic microangiopathy.        N
# 1         Alcohol intoxication        N         Alcohol intoxication        N
# 2           Coccidioidomycosis        N               Histoplasmosis        Y
# 3          Psoriatic arthritis        Y          Psoriatic arthritis        Y
# 4       Intestinal obstruction        N                Gastroschisis        N
#
#                        new_DR DR Grade  ... DR Grade.1  \
# 0  Thrombotic microangiopathy        N  ...          Y
# 1        Alcohol intoxication        N  ...          N
# 2            Fungal infection        N  ...          Y
# 3         Psoriatic arthritis        Y  ...          Y
# 4            Duodenal atresia        Y  ...          Y
#
#                             IR  \
# 0  Atheroembolic renal disease
# 1    Wernicke's encephalopathy
# 2               Histoplasmosis
# 3          Psoriatic Arthritis
# 4               Meconium ileus
#
#                                          Rationale.2 IR Grade.1  \
# 0  This patient has decreased urinary output, mal...          Y
# 1  This patient's symptoms of altered mental stat...          N
# 2  This patient presents with fever, cough, chest...          Y
# 3  The patient's clinical presentation suggests p...          Y
# 4  This neonate's clinical presentation of biliou...          N
#
#                           AR  \
# 0       Cholesterol embolism
# 1  Wernicke's encephalopathy
# 2             Histoplasmosis
# 3        Psoriatic Arthritis
# 4         Intestinal atresia
#
#                                          Rationale.3 AR Grade.1  \
# 0  The patient's recent history of cardiac cathet...          Y
# 1  The patient's symptoms (somnolence, slurred sp...          N
# 2  The patient's history of recent hiking in Miss...          Y
# 3  The patient presents with several features sug...          Y
# 4  The symptoms presented by this neonate, such a...          Y
#
#                                   BR  \
# 0       Contrast-induced nephropathy
# 1          Wernicke's encephalopathy
# 2             Histoplasma capsulatum
# 3                Psoriatic Arthritis
# 4  Duodenal atresia in Down Syndrome
#
#                                          Rationale.4 BR Grade.1
# 0  This patient's symptoms and clinical history s...          N
# 1  The prior probability of Wernicke's encephalop...          N
# 2  The prior probability of Histoplasmosis (a fun...          Y
# 3  The prior probability of psoriatic arthritis i...          Y
# 4  In Bayesian reasoning, we begin with a prior p...          Y
#
# [5 rows x 28 columns]

# %%
med_qa_data.columns
# Out:
# Index(['question', 'answer', 'new_IR', 'IR Grade', 'new_AR', 'AR Grade',
#        'new_BR', 'BR Grade', 'new_DR', 'DR Grade', 'CoT', 'CoT.1', 'GPT-4->',
#        'CoT.2', 'Rationale', 'CoT Grade', 'DR', 'Rationale.1', 'DR Grade.1',
#        'IR', 'Rationale.2', 'IR Grade.1', 'AR', 'Rationale.3', 'AR Grade.1',
#        'BR', 'Rationale.4', 'BR Grade.1'],
#       dtype='object')

# %%
# separate out the gpt 3.5 responses from the gpt4 responses - these are all listed after the 'GPT-4->' column
gpt4_cols = ['CoT.2', 'Rationale', 'CoT Grade', 'DR', 'Rationale.1', 'DR Grade.1',
       'IR', 'Rationale.2', 'IR Grade.1', 'AR', 'Rationale.3', 'AR Grade.1',
       'BR', 'Rationale.4', 'BR Grade.1']
gpt_4_responses = med_qa_data[['question','answer', *gpt4_cols]]

# the last row is a total row, so leave it out
gpt_4_responses = gpt_4_responses.iloc[0:len(gpt_4_responses) - 1]

# %%
# dropping the na answer rows from the gpt_4_responses

gpt_4_responses[np.any(gpt_4_responses[gpt4_cols].isna(), axis = 1)]
# Out:
#                                               question  \
# 50   A 36-year-old woman comes to the physician bec...
# 51   A 45-year-old man presents to the physician be...
# 97   A 75-year-old man comes to the physician for t...
# 114  A patient presents to the emergency department...
# 179  A 50-year-old man comes to the physician for a...
# 189  A 63-year-old man comes to the physician for t...
# 192  A 7-month-old boy is brought to the pediatrici...
# 196  A 77-year-old woman is brought to her primary ...
# 208  A 24-year-old man is brought to the physician ...
# 279  A 32-year-old man comes to the physician becau...
# 280  A 28-year-old woman is brought to the emergenc...
# 288  A 55-year-old woman is brought to the emergenc...
# 310  A 42-year-old man comes to the physician becau...
# 323  An 11-year-old male presents to the pediatrici...
# 343  A 4-year-old boy is brought to the physician b...
# 389  After an initial assessment in the emergency d...
# 440  You are the intern on the labor and delivery f...
# 458  A 35-year-old man attends an appointment with ...
#
#                                                 answer  \
# 50                  Papillary carcinoma of the thyroid
# 51                               Pseudomonas keratitis
# 97                               Aortic valve stenosis
# 114                                Medication reaction
# 179                                    Epidermoid cyst
# 189                                 Malignant melanoma
# 192                                         Aldolase B
# 196                                 Lewy body dementia
# 208                                      Osteoclastoma
# 279                              Chlamydia trachomatis
# 280                      Elevated sympathetic response
# 288                                  Capillary leakage
# 310                            Cutaneous larva migrans
# 323  Trinucleotide  GAA  repeat expansion on chromo...
# 343                             Chiari II malformation
# 389                                Arterial dissection
# 440                             Fetal head compression
# 458                              Presence of Barr body
#
#                                                  CoT.2  \
# 50                                      Thyroid cancer
# 51                            Insufficient information
# 97                                                 NaN
# 114  The patient presented to the emergency departm...
# 179  Apologies, but there's a missing component in ...
# 189                                                NaN
# 192                                                NaN
# 196                                                NaN
# 208                                                NaN
# 279                                                NaN
# 280                                                NaN
# 288                                                NaN
# 310                                                NaN
# 323                                                NaN
# 343                                                NaN
# 389                                                NaN
# 440                                                NaN
# 458                                                NaN
#
#                                              Rationale CoT Grade  \
# 50   This patient presents with a painless lump on ...         Y
# 51   The question is missing the photograph of the ...         N
# 97                                                 NaN       NaN
# 114                                    Ischemic stroke       NaN
# 179                                                NaN         N
# 189                                                NaN       NaN
# 192                                                NaN       NaN
# 196                                                NaN       NaN
# 208                                                NaN       NaN
# 279                                                NaN       NaN
# 280                                                NaN       NaN
# 288                                                NaN       NaN
# 310                                                NaN       NaN
# 323                                                NaN       NaN
# 343                                                NaN       NaN
# 389                                                NaN       NaN
# 440                                                NaN       NaN
# 458                                                NaN       NaN
#
#                                                     DR  \
# 50                                      Thyroid cancer
# 51                                                 NaN
# 97                                                 NaN
# 114  The differential diagnosis for this patient co...
# 179  In the absence of a provided photograph, we'll...
# 189                                                NaN
# 192                                                NaN
# 196                                                NaN
# 208                                                NaN
# 279                                                NaN
# 280                                                NaN
# 288                                                NaN
# 310                                                NaN
# 323                                                NaN
# 343                                                NaN
# 389                                                NaN
# 440                                                NaN
# 458                                                NaN
#
#                                            Rationale.1 DR Grade.1  \
# 50   The differential for this patient includes: be...          Y
# 51                                                 NaN        NaN
# 97                                                 NaN        NaN
# 114                  Cerebrovascular Accident (Stroke)          N
# 179                                     Sebaceous cyst          N
# 189                                                NaN        NaN
# 192                                                NaN        NaN
# 196                                                NaN        NaN
# 208                                                NaN        NaN
# 279                                                NaN        NaN
# 280                                                NaN        NaN
# 288                                                NaN        NaN
# 310                                                NaN        NaN
# 323                                                NaN        NaN
# 343                                                NaN        NaN
# 389                                                NaN        NaN
# 440                                                NaN        NaN
# 458                                                NaN        NaN
#
#                                                     IR  \
# 50                         Papillary thyroid carcinoma
# 51                                                 NaN
# 97                                                 NaN
# 114  This patient presents with severe headache tha...
# 179  Without an actual photograph or detailed descr...
# 189                                                NaN
# 192                                                NaN
# 196                                                NaN
# 208                                                NaN
# 279                                                NaN
# 280                                                NaN
# 288                                                NaN
# 310                                                NaN
# 323                                                NaN
# 343                                                NaN
# 389                                                NaN
# 440                                                NaN
# 458                                                NaN
#
#                                            Rationale.2 IR Grade.1  \
# 50   This patient presents with a painless lump on ...          Y
# 51                                                 NaN        NaN
# 97                                                 NaN        NaN
# 114                 Medication-induced ischemic stroke          Y
# 179                                             Lipoma          N
# 189                                                NaN        NaN
# 192                                                NaN        NaN
# 196                                                NaN        NaN
# 208                                                NaN        NaN
# 279                                                NaN        NaN
# 280                                                NaN        NaN
# 288                                                NaN        NaN
# 310                                                NaN        NaN
# 323                                                NaN        NaN
# 343                                                NaN        NaN
# 389                                                NaN        NaN
# 440                                                NaN        NaN
# 458                                                NaN        NaN
#
#                                                     AR  \
# 50                         Papillary thyroid carcinoma
# 51                                                 NaN
# 97                                                 NaN
# 114  This patient's presentation is consistent with...
# 179  Since no photograph or further description of ...
# 189                                                NaN
# 192                                                NaN
# 196                                                NaN
# 208                                                NaN
# 279                                                NaN
# 280                                                NaN
# 288                                                NaN
# 310                                                NaN
# 323                                                NaN
# 343                                                NaN
# 389                                                NaN
# 440                                                NaN
# 458                                                NaN
#
#                                            Rationale.3 AR Grade.1  \
# 50   The presence of a painless, firm, and irregula...          Y
# 51                                                 NaN        NaN
# 97                                                 NaN        NaN
# 114                                    Ischemic stroke          N
# 179                                             Lipoma          N
# 189                                                NaN        NaN
# 192                                                NaN        NaN
# 196                                                NaN        NaN
# 208                                                NaN        NaN
# 279                                                NaN        NaN
# 280                                                NaN        NaN
# 288                                                NaN        NaN
# 310                                                NaN        NaN
# 323                                                NaN        NaN
# 343                                                NaN        NaN
# 389                                                NaN        NaN
# 440                                                NaN        NaN
# 458                                                NaN        NaN
#
#                                                     BR  \
# 50                                                 NaN
# 51                                                 NaN
# 97                                                 NaN
# 114  The prior probability of a stroke in a relativ...
# 179  The prior probability of metastatic disease in...
# 189                                                NaN
# 192                                                NaN
# 196                                                NaN
# 208                                                NaN
# 279                                                NaN
# 280                                                NaN
# 288                                                NaN
# 310                                                NaN
# 323                                                NaN
# 343                                                NaN
# 389                                                NaN
# 440                                                NaN
# 458                                                NaN
#
#                                            Rationale.4 BR Grade.1
# 50   The prior probability of thyroid cancer in a y...        NaN
# 51                                                 NaN        NaN
# 97                                                 NaN        NaN
# 114                                             Stroke          N
# 179                            Metastatic colon cancer          N
# 189                                                NaN        NaN
# 192                                                NaN        NaN
# 196                                                NaN        NaN
# 208                                                NaN        NaN
# 279                                                NaN        NaN
# 280                                                NaN        NaN
# 288                                                NaN        NaN
# 310                                                NaN        NaN
# 323                                                NaN        NaN
# 343                                                NaN        NaN
# 389                                                NaN        NaN
# 440                                                NaN        NaN
# 458                                                NaN        NaN

# %%
gpt_4_responses = gpt_4_responses[~np.any(gpt_4_responses[gpt4_cols].isna(), axis = 1)]

# %%
gpt_4_responses.shape
# Out:
# (494, 17)

# %%
gpt_35_responses = med_qa_data[['question','answer','new_IR', 'IR Grade', 'new_AR', 'AR Grade',
       'new_BR', 'BR Grade', 'new_DR', 'DR Grade', 'CoT', 'CoT.1']]

gpt_35_responses = gpt_35_responses.iloc[0:len(gpt_35_responses) - 1]

# %%
gpt_4_responses.head()
# Out:
#                                             question  \
# 0  Two weeks after undergoing an emergency cardia...
# 1  A 46-year-old man is brought to the emergency ...
# 2  A 30-year-old African American woman comes to ...
# 3  A 67-year-old man who was diagnosed with arthr...
# 4  A one-day-old male is evaluated in the hospita...
#
#                              answer                              CoT.2  \
# 0          Cholesterol embolization  Cholesterol embolization syndrome
# 1       Benzodiazepine intoxication               Alcoholic neuropathy
# 2  Histoplasma capsulatum infection                     Histoplasmosis
# 3               Psoriatic arthritis                Psoriatic Arthritis
# 4                  Duodenal atresia                   Duodenal atresia
#
#                                            Rationale CoT Grade  \
# 0  This patient's presentation of decreased urina...         Y
# 1  This patient presents with altered mental stat...         N
# 2  This patient has recently been hiking in Missi...         Y
# 3  This patient has a long history of arthritis a...         Y
# 4  The baby in question is displaying signs of in...         Y
#
#                                   DR  \
# 0  Cholesterol embolization syndrome
# 1                 Cerebellar disease
# 2                     Histoplasmosis
# 3                Psoriatic Arthritis
# 4                   Duodenal atresia
#
#                                          Rationale.1 DR Grade.1  \
# 0  The differential for this patient includes acu...          Y
# 1  The differential for this patient includes alc...          N
# 2  The differential diagnosis in this case includ...          Y
# 3  The differential diagnosis for this patient in...          Y
# 4  This neonate presents with bilious vomiting, a...          Y
#
#                             IR  \
# 0  Atheroembolic renal disease
# 1    Wernicke's encephalopathy
# 2               Histoplasmosis
# 3          Psoriatic Arthritis
# 4               Meconium ileus
#
#                                          Rationale.2 IR Grade.1  \
# 0  This patient has decreased urinary output, mal...          Y
# 1  This patient's symptoms of altered mental stat...          N
# 2  This patient presents with fever, cough, chest...          Y
# 3  The patient's clinical presentation suggests p...          Y
# 4  This neonate's clinical presentation of biliou...          N
#
#                           AR  \
# 0       Cholesterol embolism
# 1  Wernicke's encephalopathy
# 2             Histoplasmosis
# 3        Psoriatic Arthritis
# 4         Intestinal atresia
#
#                                          Rationale.3 AR Grade.1  \
# 0  The patient's recent history of cardiac cathet...          Y
# 1  The patient's symptoms (somnolence, slurred sp...          N
# 2  The patient's history of recent hiking in Miss...          Y
# 3  The patient presents with several features sug...          Y
# 4  The symptoms presented by this neonate, such a...          Y
#
#                                   BR  \
# 0       Contrast-induced nephropathy
# 1          Wernicke's encephalopathy
# 2             Histoplasma capsulatum
# 3                Psoriatic Arthritis
# 4  Duodenal atresia in Down Syndrome
#
#                                          Rationale.4 BR Grade.1
# 0  This patient's symptoms and clinical history s...          N
# 1  The prior probability of Wernicke's encephalop...          N
# 2  The prior probability of Histoplasmosis (a fun...          Y
# 3  The prior probability of psoriatic arthritis i...          Y
# 4  In Bayesian reasoning, we begin with a prior p...          Y

# %% [markdown]
# ## Below is the template that the researchers used to get their responses
#
# Got this from the GPT3.5_API.ipynb notebook

# %%
qa_template = (
    "Diagnose the patients condition using the given passage with a short factoid answer.\n"
    "Question: {question}\n"
    "Rationale: a step-by-step deduction that identifies the correct response. {prompt}"
               )

# %%
from lib.llms import PromptTemplate

prompt_template = PromptTemplate(qa_template)

# %%
print(prompt_template.populate(question = "this is my special question", prompt = "this is a COT prompt"))
# Out:
# Diagnose the patients condition using the given passage with a short factoid answer.
# Question: this is my special question
# Rationale: a step-by-step deduction that identifies the correct response. this is a COT prompt

# %%
# intuitive
ir_prompt = "Use symptom, signs and laboratory disease associations to step by step deduce the correct response"

# differential
dr_prompt = "Use step by step deduction to create a differential diagnosis and then use step by step deduction to determine the correct response."

# analytic
ar_prompt = "Use analytic reasoning to deduce the physiologic or biochemical pathophysiology of the patient and step by step identify the correct response."

# bayesian
br_prompt = "Use step by step Bayesian Inference to create a prior probability that is updated with new information in the history to produce a posterior probability and determine the final diagnosis."

# %% [markdown]
# ## populate the prompt template with a real question and prompt from the dataset

# %%
to_send = prompt_template.populate( question = gpt_4_responses['question'][0], prompt = dr_prompt)
print(to_send)
# Out:
# Diagnose the patients condition using the given passage with a short factoid answer.
# Question: Two weeks after undergoing an emergency cardiac catherization with stenting for unstable angina pectoris, a 61-year-old man has decreased urinary output and malaise. He has type 2 diabetes mellitus and osteoarthritis of the hips. Prior to admission, his medications were insulin and naproxen. He was also started on aspirin, clopidogrel, and metoprolol after the coronary intervention. His temperature is 38°C (100.4°F), pulse is 93/min, and blood pressure is 125/85 mm Hg. Examination shows mottled, reticulated purplish discoloration of the feet. Laboratory studies show:
# Hemoglobin count 14 g/dL
# Leukocyte count 16,400/mm3
# Segmented neutrophils 56%
# Eosinophils 11%
# Lymphocytes 31%
# Monocytes 2%
# Platelet count 260,000/mm3
# Erythrocyte sedimentation rate 68 mm/h
# Serum
# Urea nitrogen 25 mg/dL
# Creatinine 4.2 mg/dL
# Renal biopsy shows intravascular spindle-shaped vacuoles. What is the most likely cause of this patient's symptoms?"
# Rationale: a step-by-step deduction that identifies the correct response. Use step by step deduction to create a differential diagnosis and then use step by step deduction to determine the correct response.

# %% [markdown]
# Lets see what GPT 4o gives back when we ask this question

# %%
from lib.llms.chats import ChatOpenAI

llm_4o = ChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4
)

# %%
res = llm_4o(to_send)

# %%
print(res.text)
# Out:
# Based on the information provided in the passage, let's go through the step-by-step deduction process for diagnosing the patient's condition:
#
# 1. **Patient Background and Symptoms:**
#    - The patient is a 61-year-old man who underwent cardiac catheterization with stenting for unstable angina.
#    - He has decreased urinary output and malaise.
#    - He has a medical history of type 2 diabetes mellitus and osteoarthritis, and post-intervention medications include aspirin, clopidogrel, and metoprolol.
#    - He presents with a temperature of 38°C, pulse 93/min, blood pressure 125/85 mmHg, and mottled, reticulated purplish discoloration of the feet.
#
# 2. **Laboratory Findings:**
#    - Elevated leukocyte count with eosinophilia (11% eosinophils).
#    - Elevated erythrocyte sedimentation rate (ESR).
#    - Elevated serum creatinine (4.2 mg/dL) and urea nitrogen (25 mg/dL), indicating renal impairment.
#    - Renal biopsy shows intravascular spindle-shaped vacuoles.
#
# 3. **Possible Diagnoses:**
#    - **Acute interstitial nephritis (AIN):** Usually associated with eosinophilia and can be induced by drugs like NSAIDs or antibiotics. However, the renal biopsy findings aren't characteristic of AIN.
#    - **Contrast-induced nephropathy:** Common after cardiac catheterization but usually resolves within a few days and lacks eosinophilia.
#    - **Cholesterol embolization syndrome (CES):** Characterized by acute kidney injury, eosinophilia, elevated ESR, and skin changes such as livedo reticularis (mottling). Renal biopsy showing cholesterol clefts or intravascular spindle-shaped vacuoles is suggestive of CES.
#
# 4. **Final Deduction:**
#    - The combination of decreased urinary output, eosinophilia, elevated ESR, mottled purplish discoloration of the feet, and renal biopsy findings strongly suggest cholesterol embolization syndrome. The condition typically occurs after procedures like cardiac catheterization, which can dislodge cholesterol crystals from atherosclerotic plaques, leading to systemic emboli.
#
# **Conclusion:**
# The most likely cause of this patient's symptoms is cholesterol embolization syndrome (CES).

# %% [markdown]
# # Before I go any further, lets create a rudimentary eval harness

# %%
def eval_responses(response_df: pd.DataFrame, true_col:str, llm_res: list):
    '''
    Given a dataframe of responses, a true column label that is in the dataframe and an array of
    responses from the llm
    test whether answer from the true column is contained within the corresponding llm_res element

    ex: question: What color is the sky? answer = blue, llm_res = "the sky is blue" would evaluate to True
    '''
    no_nulls = response_df[~response_df[true_col].isna()].reset_index()
    true_answers = no_nulls[true_col]
    
    correct = pd.Series([a.lower() in b.lower() for a, b in zip(true_answers, llm_res)])

    print(f'# correct = {correct.sum()} / {len(correct)}')

    return correct.sum() / len(correct)


def get_incorrect(response_df: pd.DataFrame, true_col:str, llm_res: list):

    no_nulls = response_df[~response_df[true_col].isna()].reset_index()
    true_answers = no_nulls[true_col]
    
    correct = pd.Series([a.lower() in b.lower() for a, b in zip(true_answers, llm_res)])

    incorrect_df = no_nulls[~correct]

    incorrect_llm_responses = [llm_res[i] for i in incorrect_df.index]

    incorrect_df['llm_responses'] = incorrect_llm_responses

    return incorrect_df[['question', true_col, 'llm_responses']]

# %% [markdown]
# ## lets test this out on the study responses
#
# ### We can see that that answers that were marked as correct don't *exactly* match the "golden answer" (adhd = "attention deficit hyperactivity disorder")
#
# I don't expect this to replicate exactly because the answers from the study were graded by real human doctors

# %%
study_answer_cols = ['CoT.2', 'DR',
       'IR', 'AR','BR']

study_responses = [gpt_4_responses[col].values for col in study_answer_cols]

for i, col in enumerate(study_answer_cols):
       percent = eval_responses(gpt_4_responses, 'answer', study_responses[i])
       print(f'reasoning type {col} = {percent * 100}%')
# Out:
# # correct = 177 / 494
# reasoning type CoT.2 = 35.82995951417004%
# # correct = 201 / 494
# reasoning type DR = 40.688259109311744%
# # correct = 192 / 494
# reasoning type IR = 38.8663967611336%
# # correct = 191 / 494
# reasoning type AR = 38.663967611336034%
# # correct = 164 / 494
# reasoning type BR = 33.198380566801625%

# %% [markdown]
# ## As you can see from above, DR is still the best, and the results here don't match the study results. We could get a lot fancier with the evaluation, but we are really interested for this session in prompt engineering
#
#
#
# #### Now I'm going to define a function that will take in an array of the MedQA questions and then hit an LLM with them and get the answers
#
# The template that I'm going to use will have the keywords "context" and "question". The "context" variable is where we will put the real medical question (sorry confusing) and the "question" variable is where we will put our prompt

# %%
from json import JSONDecodeError
from collections import defaultdict
from lib.reasoning.pipelines.answer_with_context import AnswerWithContextPipeline
from itertools import islice
import time
import asyncio
from typing import Union
import numpy as np



def batch_tasks(iterable, batch_size):
    iterator = iter(iterable)
    while True:
        batch = list(islice(iterator, batch_size))
        if not batch:
            break
        yield batch


async def async_get_answer(answer_with_context_pipeline: AnswerWithContextPipeline, prompt: str, evidence: str, history = []):
    try:
        extracted_answer = await answer_with_context_pipeline.ainvoke(question = prompt, evidence = evidence, history = history)

        return extracted_answer
    except Exception as e:
        print(e)
        return {"explanation": "Failed to parse",  'reason': e}
    

async def async_answer(answer_with_context_pipeline: AnswerWithContextPipeline, prompt, evidence_arr, batch_size = 100, history = []):
    n_data = len(evidence_arr)
    
    tasks = []
    for i, evidence in enumerate(evidence_arr):
        print(f'====== \n processing {i + 1}/{n_data} files \n')

        tasks.append(async_get_answer(answer_with_context_pipeline, prompt, evidence, history = history))

    extracted_answers = []
    needs_reprocessing = []
    for batch_number, batch in enumerate(batch_tasks(tasks, batch_size)):
        print(f'processing batch {batch_number} of size {batch_size}')
        settled_tasks = await asyncio.gather(*batch)
        for i,initial_extraction in enumerate(settled_tasks):
            idx = batch_number*batch_size + i
            if isinstance(initial_extraction, dict):
                needs_reprocessing.append(initial_extraction)
                extracted_answers.append(initial_extraction)
            else:
                try:
                    parsed_initial_extraction = json.loads(initial_extraction.content)

                    extracted_answers.append(parsed_initial_extraction)

                except JSONDecodeError as e:
                    needs_reprocessing.append({"answer": "Failed to parse", "idx": idx, 'reason': e})
                    extracted_answers.append(initial_extraction.content)
        # avoid rate limit
        time.sleep(6)
        
    return extracted_answers, needs_reprocessing

# %%
# All of the questions that we want responded too
questions = gpt_4_responses['question'].values

qa_template = (
    "Question: {context}\n"
    "Rationale: a step-by-step deduction that identifies the correct response. {question}" # remember this is where the prompt goes
    )

llm_4o = ChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4
)


answer_pipeline = AnswerWithContextPipeline(
    llm = llm_4o,
    qa_template = qa_template
    # system_prompt="you could put a system prompt here"
)

# %%
dr_answers, need_reprocess = await async_answer(answer_pipeline, dr_prompt, questions, batch_size = 100)
# Out:
# ======
#  processing 1/494 files
#
# ======
#  processing 2/494 files
#
# ======
#  processing 3/494 files
#
# ======
#  processing 4/494 files
#
# ======
#  processing 5/494 files
#
# ======
#  processing 6/494 files
#
# ======
#  processing 7/494 files
#
# ======
#  processing 8/494 files
#
# ======
#  processing 9/494 files
#
# ======
#  processing 10/494 files
#
# ======
#  processing 11/494 files
#
# ======
#  processing 12/494 files
#
# ======
#  processing 13/494 files
#
# ======
#  processing 14/494 files
#
# ======
#  processing 15/494 files
#
# ======
#  processing 16/494 files
#
# ======
#  processing 17/494 files
#
# ======
#  processing 18/494 files
#
# ======
#  processing 19/494 files
#
# ======
#  processing 20/494 files
#
# ======
#  processing 21/494 files
#
# ======
#  processing 22/494 files
#
# ======
#  processing 23/494 files
#
# ======
#  processing 24/494 files
#
# ======
#  processing 25/494 files
#
# ======
#  processing 26/494 files
#
# ======
#  processing 27/494 files
#
# ======
#  processing 28/494 files
#
# ======
#  processing 29/494 files
#
# ======
#  processing 30/494 files
#
# ======
#  processing 31/494 files
#
# ======
#  processing 32/494 files
#
# ======
#  processing 33/494 files
#
# ======
#  processing 34/494 files
#
# ======
#  processing 35/494 files
#
# ======
#  processing 36/494 files
#
# ======
#  processing 37/494 files
#
# ======
#  processing 38/494 files
#
# ======
#  processing 39/494 files
#
# ======
#  processing 40/494 files
#
# ======
#  processing 41/494 files
#
# ======
#  processing 42/494 files
#
# ======
#  processing 43/494 files
#
# ======
#  processing 44/494 files
#
# ======
#  processing 45/494 files
#
# ======
#  processing 46/494 files
#
# ======
#  processing 47/494 files
#
# ======
#  processing 48/494 files
#
# ======
#  processing 49/494 files
#
# ======
#  processing 50/494 files
#
# ======
#  processing 51/494 files
#
# ======
#  processing 52/494 files
#
# ======
#  processing 53/494 files
#
# ======
#  processing 54/494 files
#
# ======
#  processing 55/494 files
#
# ======
#  processing 56/494 files
#
# ======
#  processing 57/494 files
#
# ======
#  processing 58/494 files
#
# ======
#  processing 59/494 files
#
# ======
#  processing 60/494 files
#
# ======
#  processing 61/494 files
#
# ======
#  processing 62/494 files
#
# ======
#  processing 63/494 files
#
# ======
#  processing 64/494 files
#
# ======
#  processing 65/494 files
#
# ======
#  processing 66/494 files
#
# ======
#  processing 67/494 files
#
# ======
#  processing 68/494 files
#
# ======
#  processing 69/494 files
#
# ======
#  processing 70/494 files
#
# ======
#  processing 71/494 files
#
# ======
#  processing 72/494 files
#
# ======
#  processing 73/494 files
#
# ======
#  processing 74/494 files
#
# ======
#  processing 75/494 files
#
# ======
#  processing 76/494 files
#
# ======
#  processing 77/494 files
#
# ======
#  processing 78/494 files
#
# ======
#  processing 79/494 files
#
# ======
#  processing 80/494 files
#
# ======
#  processing 81/494 files
#
# ======
#  processing 82/494 files
#
# ======
#  processing 83/494 files
#
# ======
#  processing 84/494 files
#
# ======
#  processing 85/494 files
#
# ======
#  processing 86/494 files
#
# ======
#  processing 87/494 files
#
# ======
#  processing 88/494 files
#
# ======
#  processing 89/494 files
#
# ======
#  processing 90/494 files
#
# ======
#  processing 91/494 files
#
# ======
#  processing 92/494 files
#
# ======
#  processing 93/494 files
#
# ======
#  processing 94/494 files
#
# ======
#  processing 95/494 files
#
# ======
#  processing 96/494 files
#
# ======
#  processing 97/494 files
#
# ======
#  processing 98/494 files
#
# ======
#  processing 99/494 files
#
# ======
#  processing 100/494 files
#
# ======
#  processing 101/494 files
#
# ======
#  processing 102/494 files
#
# ======
#  processing 103/494 files
#
# ======
#  processing 104/494 files
#
# ======
#  processing 105/494 files
#
# ======
#  processing 106/494 files
#
# ======
#  processing 107/494 files
#
# ======
#  processing 108/494 files
#
# ======
#  processing 109/494 files
#
# ======
#  processing 110/494 files
#
# ======
#  processing 111/494 files
#
# ======
#  processing 112/494 files
#
# ======
#  processing 113/494 files
#
# ======
#  processing 114/494 files
#
# ======
#  processing 115/494 files
#
# ======
#  processing 116/494 files
#
# ======
#  processing 117/494 files
#
# ======
#  processing 118/494 files
#
# ======
#  processing 119/494 files
#
# ======
#  processing 120/494 files
#
# ======
#  processing 121/494 files
#
# ======
#  processing 122/494 files
#
# ======
#  processing 123/494 files
#
# ======
#  processing 124/494 files
#
# ======
#  processing 125/494 files
#
# ======
#  processing 126/494 files
#
# ======
#  processing 127/494 files
#
# ======
#  processing 128/494 files
#
# ======
#  processing 129/494 files
#
# ======
#  processing 130/494 files
#
# ======
#  processing 131/494 files
#
# ======
#  processing 132/494 files
#
# ======
#  processing 133/494 files
#
# ======
#  processing 134/494 files
#
# ======
#  processing 135/494 files
#
# ======
#  processing 136/494 files
#
# ======
#  processing 137/494 files
#
# ======
#  processing 138/494 files
#
# ======
#  processing 139/494 files
#
# ======
#  processing 140/494 files
#
# ======
#  processing 141/494 files
#
# ======
#  processing 142/494 files
#
# ======
#  processing 143/494 files
#
# ======
#  processing 144/494 files
#
# ======
#  processing 145/494 files
#
# ======
#  processing 146/494 files
#
# ======
#  processing 147/494 files
#
# ======
#  processing 148/494 files
#
# ======
#  processing 149/494 files
#
# ======
#  processing 150/494 files
#
# ======
#  processing 151/494 files
#
# ======
#  processing 152/494 files
#
# ======
#  processing 153/494 files
#
# ======
#  processing 154/494 files
#
# ======
#  processing 155/494 files
#
# ======
#  processing 156/494 files
#
# ======
#  processing 157/494 files
#
# ======
#  processing 158/494 files
#
# ======
#  processing 159/494 files
#
# ======
#  processing 160/494 files
#
# ======
#  processing 161/494 files
#
# ======
#  processing 162/494 files
#
# ======
#  processing 163/494 files
#
# ======
#  processing 164/494 files
#
# ======
#  processing 165/494 files
#
# ======
#  processing 166/494 files
#
# ======
#  processing 167/494 files
#
# ======
#  processing 168/494 files
#
# ======
#  processing 169/494 files
#
# ======
#  processing 170/494 files
#
# ======
#  processing 171/494 files
#
# ======
#  processing 172/494 files
#
# ======
#  processing 173/494 files
#
# ======
#  processing 174/494 files
#
# ======
#  processing 175/494 files
#
# ======
#  processing 176/494 files
#
# ======
#  processing 177/494 files
#
# ======
#  processing 178/494 files
#
# ======
#  processing 179/494 files
#
# ======
#  processing 180/494 files
#
# ======
#  processing 181/494 files
#
# ======
#  processing 182/494 files
#
# ======
#  processing 183/494 files
#
# ======
#  processing 184/494 files
#
# ======
#  processing 185/494 files
#
# ======
#  processing 186/494 files
#
# ======
#  processing 187/494 files
#
# ======
#  processing 188/494 files
#
# ======
#  processing 189/494 files
#
# ======
#  processing 190/494 files
#
# ======
#  processing 191/494 files
#
# ======
#  processing 192/494 files
#
# ======
#  processing 193/494 files
#
# ======
#  processing 194/494 files
#
# ======
#  processing 195/494 files
#
# ======
#  processing 196/494 files
#
# ======
#  processing 197/494 files
#
# ======
#  processing 198/494 files
#
# ======
#  processing 199/494 files
#
# ======
#  processing 200/494 files
#
# ======
#  processing 201/494 files
#
# ======
#  processing 202/494 files
#
# ======
#  processing 203/494 files
#
# ======
#  processing 204/494 files
#
# ======
#  processing 205/494 files
#
# ======
#  processing 206/494 files
#
# ======
#  processing 207/494 files
#
# ======
#  processing 208/494 files
#
# ======
#  processing 209/494 files
#
# ======
#  processing 210/494 files
#
# ======
#  processing 211/494 files
#
# ======
#  processing 212/494 files
#
# ======
#  processing 213/494 files
#
# ======
#  processing 214/494 files
#
# ======
#  processing 215/494 files
#
# ======
#  processing 216/494 files
#
# ======
#  processing 217/494 files
#
# ======
#  processing 218/494 files
#
# ======
#  processing 219/494 files
#
# ======
#  processing 220/494 files
#
# ======
#  processing 221/494 files
#
# ======
#  processing 222/494 files
#
# ======
#  processing 223/494 files
#
# ======
#  processing 224/494 files
#
# ======
#  processing 225/494 files
#
# ======
#  processing 226/494 files
#
# ======
#  processing 227/494 files
#
# ======
#  processing 228/494 files
#
# ======
#  processing 229/494 files
#
# ======
#  processing 230/494 files
#
# ======
#  processing 231/494 files
#
# ======
#  processing 232/494 files
#
# ======
#  processing 233/494 files
#
# ======
#  processing 234/494 files
#
# ======
#  processing 235/494 files
#
# ======
#  processing 236/494 files
#
# ======
#  processing 237/494 files
#
# ======
#  processing 238/494 files
#
# ======
#  processing 239/494 files
#
# ======
#  processing 240/494 files
#
# ======
#  processing 241/494 files
#
# ======
#  processing 242/494 files
#
# ======
#  processing 243/494 files
#
# ======
#  processing 244/494 files
#
# ======
#  processing 245/494 files
#
# ======
#  processing 246/494 files
#
# ======
#  processing 247/494 files
#
# ======
#  processing 248/494 files
#
# ======
#  processing 249/494 files
#
# ======
#  processing 250/494 files
#
# ======
#  processing 251/494 files
#
# ======
#  processing 252/494 files
#
# ======
#  processing 253/494 files
#
# ======
#  processing 254/494 files
#
# ======
#  processing 255/494 files
#
# ======
#  processing 256/494 files
#
# ======
#  processing 257/494 files
#
# ======
#  processing 258/494 files
#
# ======
#  processing 259/494 files
#
# ======
#  processing 260/494 files
#
# ======
#  processing 261/494 files
#
# ======
#  processing 262/494 files
#
# ======
#  processing 263/494 files
#
# ======
#  processing 264/494 files
#
# ======
#  processing 265/494 files
#
# ======
#  processing 266/494 files
#
# ======
#  processing 267/494 files
#
# ======
#  processing 268/494 files
#
# ======
#  processing 269/494 files
#
# ======
#  processing 270/494 files
#
# ======
#  processing 271/494 files
#
# ======
#  processing 272/494 files
#
# ======
#  processing 273/494 files
#
# ======
#  processing 274/494 files
#
# ======
#  processing 275/494 files
#
# ======
#  processing 276/494 files
#
# ======
#  processing 277/494 files
#
# ======
#  processing 278/494 files
#
# ======
#  processing 279/494 files
#
# ======
#  processing 280/494 files
#
# ======
#  processing 281/494 files
#
# ======
#  processing 282/494 files
#
# ======
#  processing 283/494 files
#
# ======
#  processing 284/494 files
#
# ======
#  processing 285/494 files
#
# ======
#  processing 286/494 files
#
# ======
#  processing 287/494 files
#
# ======
#  processing 288/494 files
#
# ======
#  processing 289/494 files
#
# ======
#  processing 290/494 files
#
# ======
#  processing 291/494 files
#
# ======
#  processing 292/494 files
#
# ======
#  processing 293/494 files
#
# ======
#  processing 294/494 files
#
# ======
#  processing 295/494 files
#
# ======
#  processing 296/494 files
#
# ======
#  processing 297/494 files
#
# ======
#  processing 298/494 files
#
# ======
#  processing 299/494 files
#
# ======
#  processing 300/494 files
#
# ======
#  processing 301/494 files
#
# ======
#  processing 302/494 files
#
# ======
#  processing 303/494 files
#
# ======
#  processing 304/494 files
#
# ======
#  processing 305/494 files
#
# ======
#  processing 306/494 files
#
# ======
#  processing 307/494 files
#
# ======
#  processing 308/494 files
#
# ======
#  processing 309/494 files
#
# ======
#  processing 310/494 files
#
# ======
#  processing 311/494 files
#
# ======
#  processing 312/494 files
#
# ======
#  processing 313/494 files
#
# ======
#  processing 314/494 files
#
# ======
#  processing 315/494 files
#
# ======
#  processing 316/494 files
#
# ======
#  processing 317/494 files
#
# ======
#  processing 318/494 files
#
# ======
#  processing 319/494 files
#
# ======
#  processing 320/494 files
#
# ======
#  processing 321/494 files
#
# ======
#  processing 322/494 files
#
# ======
#  processing 323/494 files
#
# ======
#  processing 324/494 files
#
# ======
#  processing 325/494 files
#
# ======
#  processing 326/494 files
#
# ======
#  processing 327/494 files
#
# ======
#  processing 328/494 files
#
# ======
#  processing 329/494 files
#
# ======
#  processing 330/494 files
#
# ======
#  processing 331/494 files
#
# ======
#  processing 332/494 files
#
# ======
#  processing 333/494 files
#
# ======
#  processing 334/494 files
#
# ======
#  processing 335/494 files
#
# ======
#  processing 336/494 files
#
# ======
#  processing 337/494 files
#
# ======
#  processing 338/494 files
#
# ======
#  processing 339/494 files
#
# ======
#  processing 340/494 files
#
# ======
#  processing 341/494 files
#
# ======
#  processing 342/494 files
#
# ======
#  processing 343/494 files
#
# ======
#  processing 344/494 files
#
# ======
#  processing 345/494 files
#
# ======
#  processing 346/494 files
#
# ======
#  processing 347/494 files
#
# ======
#  processing 348/494 files
#
# ======
#  processing 349/494 files
#
# ======
#  processing 350/494 files
#
# ======
#  processing 351/494 files
#
# ======
#  processing 352/494 files
#
# ======
#  processing 353/494 files
#
# ======
#  processing 354/494 files
#
# ======
#  processing 355/494 files
#
# ======
#  processing 356/494 files
#
# ======
#  processing 357/494 files
#
# ======
#  processing 358/494 files
#
# ======
#  processing 359/494 files
#
# ======
#  processing 360/494 files
#
# ======
#  processing 361/494 files
#
# ======
#  processing 362/494 files
#
# ======
#  processing 363/494 files
#
# ======
#  processing 364/494 files
#
# ======
#  processing 365/494 files
#
# ======
#  processing 366/494 files
#
# ======
#  processing 367/494 files
#
# ======
#  processing 368/494 files
#
# ======
#  processing 369/494 files
#
# ======
#  processing 370/494 files
#
# ======
#  processing 371/494 files
#
# ======
#  processing 372/494 files
#
# ======
#  processing 373/494 files
#
# ======
#  processing 374/494 files
#
# ======
#  processing 375/494 files
#
# ======
#  processing 376/494 files
#
# ======
#  processing 377/494 files
#
# ======
#  processing 378/494 files
#
# ======
#  processing 379/494 files
#
# ======
#  processing 380/494 files
#
# ======
#  processing 381/494 files
#
# ======
#  processing 382/494 files
#
# ======
#  processing 383/494 files
#
# ======
#  processing 384/494 files
#
# ======
#  processing 385/494 files
#
# ======
#  processing 386/494 files
#
# ======
#  processing 387/494 files
#
# ======
#  processing 388/494 files
#
# ======
#  processing 389/494 files
#
# ======
#  processing 390/494 files
#
# ======
#  processing 391/494 files
#
# ======
#  processing 392/494 files
#
# ======
#  processing 393/494 files
#
# ======
#  processing 394/494 files
#
# ======
#  processing 395/494 files
#
# ======
#  processing 396/494 files
#
# ======
#  processing 397/494 files
#
# ======
#  processing 398/494 files
#
# ======
#  processing 399/494 files
#
# ======
#  processing 400/494 files
#
# ======
#  processing 401/494 files
#
# ======
#  processing 402/494 files
#
# ======
#  processing 403/494 files
#
# ======
#  processing 404/494 files
#
# ======
#  processing 405/494 files
#
# ======
#  processing 406/494 files
#
# ======
#  processing 407/494 files
#
# ======
#  processing 408/494 files
#
# ======
#  processing 409/494 files
#
# ======
#  processing 410/494 files
#
# ======
#  processing 411/494 files
#
# ======
#  processing 412/494 files
#
# ======
#  processing 413/494 files
#
# ======
#  processing 414/494 files
#
# ======
#  processing 415/494 files
#
# ======
#  processing 416/494 files
#
# ======
#  processing 417/494 files
#
# ======
#  processing 418/494 files
#
# ======
#  processing 419/494 files
#
# ======
#  processing 420/494 files
#
# ======
#  processing 421/494 files
#
# ======
#  processing 422/494 files
#
# ======
#  processing 423/494 files
#
# ======
#  processing 424/494 files
#
# ======
#  processing 425/494 files
#
# ======
#  processing 426/494 files
#
# ======
#  processing 427/494 files
#
# ======
#  processing 428/494 files
#
# ======
#  processing 429/494 files
#
# ======
#  processing 430/494 files
#
# ======
#  processing 431/494 files
#
# ======
#  processing 432/494 files
#
# ======
#  processing 433/494 files
#
# ======
#  processing 434/494 files
#
# ======
#  processing 435/494 files
#
# ======
#  processing 436/494 files
#
# ======
#  processing 437/494 files
#
# ======
#  processing 438/494 files
#
# ======
#  processing 439/494 files
#
# ======
#  processing 440/494 files
#
# ======
#  processing 441/494 files
#
# ======
#  processing 442/494 files
#
# ======
#  processing 443/494 files
#
# ======
#  processing 444/494 files
#
# ======
#  processing 445/494 files
#
# ======
#  processing 446/494 files
#
# ======
#  processing 447/494 files
#
# ======
#  processing 448/494 files
#
# ======
#  processing 449/494 files
#
# ======
#  processing 450/494 files
#
# ======
#  processing 451/494 files
#
# ======
#  processing 452/494 files
#
# ======
#  processing 453/494 files
#
# ======
#  processing 454/494 files
#
# ======
#  processing 455/494 files
#
# ======
#  processing 456/494 files
#
# ======
#  processing 457/494 files
#
# ======
#  processing 458/494 files
#
# ======
#  processing 459/494 files
#
# ======
#  processing 460/494 files
#
# ======
#  processing 461/494 files
#
# ======
#  processing 462/494 files
#
# ======
#  processing 463/494 files
#
# ======
#  processing 464/494 files
#
# ======
#  processing 465/494 files
#
# ======
#  processing 466/494 files
#
# ======
#  processing 467/494 files
#
# ======
#  processing 468/494 files
#
# ======
#  processing 469/494 files
#
# ======
#  processing 470/494 files
#
# ======
#  processing 471/494 files
#
# ======
#  processing 472/494 files
#
# ======
#  processing 473/494 files
#
# ======
#  processing 474/494 files
#
# ======
#  processing 475/494 files
#
# ======
#  processing 476/494 files
#
# ======
#  processing 477/494 files
#
# ======
#  processing 478/494 files
#
# ======
#  processing 479/494 files
#
# ======
#  processing 480/494 files
#
# ======
#  processing 481/494 files
#
# ======
#  processing 482/494 files
#
# ======
#  processing 483/494 files
#
# ======
#  processing 484/494 files
#
# ======
#  processing 485/494 files
#
# ======
#  processing 486/494 files
#
# ======
#  processing 487/494 files
#
# ======
#  processing 488/494 files
#
# ======
#  processing 489/494 files
#
# ======
#  processing 490/494 files
#
# ======
#  processing 491/494 files
#
# ======
#  processing 492/494 files
#
# ======
#  processing 493/494 files
#
# ======
#  processing 494/494 files
#
# processing batch 0 of size 100
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# /Users/benjamindykstra/development/health-tech-llm-code-lab/venv/lib/python3.10/site-packages/numpy/lib/function_base.py:520: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# /Users/benjamindykstra/development/health-tech-llm-code-lab/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# processing batch 1 of size 100
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# processing batch 2 of size 100
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# processing batch 3 of size 100
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# processing batch 4 of size 100
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images
# Got 0 images

# %%
eval_responses(gpt_4_responses, 'answer', dr_answers)
# Out:
# # correct = 256 / 494
# 0.5182186234817814

# %% [markdown]
# ## So already after only upgrading the model to 4o istead of 4, there's about a 10% increase in accuracy
#
#
# # assign a role and responsibility to the prompt

# %%
from lib.base import AIMessage, Document, HumanMessage, SystemMessage
from lib.llms.chats.base import ChatLLM

def get_populated_prompts(questions: list[str], template: PromptTemplate):
    return [
        template.populate(question = question)
        for question in questions
    ]

async def async_answer_from_question(llm: ChatLLM, prompt, examples: list[tuple] = [], system_prompt = ''):
    messages = []
    if system_prompt:
        messages.append(SystemMessage(content=system_prompt))

    for human, ai in examples:
        messages.append(HumanMessage(content=human))
        messages.append(AIMessage(content=ai))

    messages.append(HumanMessage(content=prompt))

    try:
        output = await llm.ainvoke(messages)

        return Document(text = output.text )
    except Exception as e:
        print("hit error async invoking in answer with context: ", e)
        raise e
    


async def async_answer(answer_with_llm: ChatLLM, questions: list[str], template: PromptTemplate, examples: list[tuple[str]] = [], system_prompt = '', batch_size = 100):
    n_data = len(questions)
    
    populated_prompts = get_populated_prompts(questions, template)
    tasks = []
    for i, pop_prompt in enumerate(populated_prompts):
        print(f'====== \n processing {i + 1}/{n_data} files \n')

        tasks.append(async_answer_from_question(answer_with_llm, pop_prompt, examples= examples, system_prompt=system_prompt))

    extracted_answers = []
    needs_reprocessing = []
    for batch_number, batch in enumerate(batch_tasks(tasks, batch_size)):
        print(f'processing batch {batch_number} of size {batch_size}')
        settled_tasks = await asyncio.gather(*batch)
        for i,initial_answer in enumerate(settled_tasks):
            idx = batch_number*batch_size + i
            if isinstance(initial_answer, dict):
                needs_reprocessing.append(initial_answer)
                extracted_answers.append(initial_answer)
            else:
                try:
                    parsed_initial_answer = json.loads(initial_answer.content)

                    extracted_answers.append(parsed_initial_answer)

                except JSONDecodeError as e:
                    needs_reprocessing.append({"answer": "Failed to parse", "idx": idx, 'reason': e})
                    extracted_answers.append(initial_answer.content)
        # avoid rate limit
        time.sleep(2)
        
    return extracted_answers, needs_reprocessing

# %%
llm_4o = ChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o-mini',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4
)


role_response_template = PromptTemplate("""
You are an expert medical doctor who carefully thinks through patients symptoms and diagnoses them.
Question: {question}
Rationale: a step-by-step deduction that identifies the correct response. Use step by step deduction to create a differential diagnosis and then use step by step deduction to determine the correct response.
""")

# %%
role_response_dr_answers, need_reprocess = await async_answer(llm_4o, questions, role_response_template, batch_size = 100)
# Out:
# ======
#  processing 1/494 files
#
# ======
#  processing 2/494 files
#
# ======
#  processing 3/494 files
#
# ======
#  processing 4/494 files
#
# ======
#  processing 5/494 files
#
# ======
#  processing 6/494 files
#
# ======
#  processing 7/494 files
#
# ======
#  processing 8/494 files
#
# ======
#  processing 9/494 files
#
# ======
#  processing 10/494 files
#
# ======
#  processing 11/494 files
#
# ======
#  processing 12/494 files
#
# ======
#  processing 13/494 files
#
# ======
#  processing 14/494 files
#
# ======
#  processing 15/494 files
#
# ======
#  processing 16/494 files
#
# ======
#  processing 17/494 files
#
# ======
#  processing 18/494 files
#
# ======
#  processing 19/494 files
#
# ======
#  processing 20/494 files
#
# ======
#  processing 21/494 files
#
# ======
#  processing 22/494 files
#
# ======
#  processing 23/494 files
#
# ======
#  processing 24/494 files
#
# ======
#  processing 25/494 files
#
# ======
#  processing 26/494 files
#
# ======
#  processing 27/494 files
#
# ======
#  processing 28/494 files
#
# ======
#  processing 29/494 files
#
# ======
#  processing 30/494 files
#
# ======
#  processing 31/494 files
#
# ======
#  processing 32/494 files
#
# ======
#  processing 33/494 files
#
# ======
#  processing 34/494 files
#
# ======
#  processing 35/494 files
#
# ======
#  processing 36/494 files
#
# ======
#  processing 37/494 files
#
# ======
#  processing 38/494 files
#
# ======
#  processing 39/494 files
#
# ======
#  processing 40/494 files
#
# ======
#  processing 41/494 files
#
# ======
#  processing 42/494 files
#
# ======
#  processing 43/494 files
#
# ======
#  processing 44/494 files
#
# ======
#  processing 45/494 files
#
# ======
#  processing 46/494 files
#
# ======
#  processing 47/494 files
#
# ======
#  processing 48/494 files
#
# ======
#  processing 49/494 files
#
# ======
#  processing 50/494 files
#
# ======
#  processing 51/494 files
#
# ======
#  processing 52/494 files
#
# ======
#  processing 53/494 files
#
# ======
#  processing 54/494 files
#
# ======
#  processing 55/494 files
#
# ======
#  processing 56/494 files
#
# ======
#  processing 57/494 files
#
# ======
#  processing 58/494 files
#
# ======
#  processing 59/494 files
#
# ======
#  processing 60/494 files
#
# ======
#  processing 61/494 files
#
# ======
#  processing 62/494 files
#
# ======
#  processing 63/494 files
#
# ======
#  processing 64/494 files
#
# ======
#  processing 65/494 files
#
# ======
#  processing 66/494 files
#
# ======
#  processing 67/494 files
#
# ======
#  processing 68/494 files
#
# ======
#  processing 69/494 files
#
# ======
#  processing 70/494 files
#
# ======
#  processing 71/494 files
#
# ======
#  processing 72/494 files
#
# ======
#  processing 73/494 files
#
# ======
#  processing 74/494 files
#
# ======
#  processing 75/494 files
#
# ======
#  processing 76/494 files
#
# ======
#  processing 77/494 files
#
# ======
#  processing 78/494 files
#
# ======
#  processing 79/494 files
#
# ======
#  processing 80/494 files
#
# ======
#  processing 81/494 files
#
# ======
#  processing 82/494 files
#
# ======
#  processing 83/494 files
#
# ======
#  processing 84/494 files
#
# ======
#  processing 85/494 files
#
# ======
#  processing 86/494 files
#
# ======
#  processing 87/494 files
#
# ======
#  processing 88/494 files
#
# ======
#  processing 89/494 files
#
# ======
#  processing 90/494 files
#
# ======
#  processing 91/494 files
#
# ======
#  processing 92/494 files
#
# ======
#  processing 93/494 files
#
# ======
#  processing 94/494 files
#
# ======
#  processing 95/494 files
#
# ======
#  processing 96/494 files
#
# ======
#  processing 97/494 files
#
# ======
#  processing 98/494 files
#
# ======
#  processing 99/494 files
#
# ======
#  processing 100/494 files
#
# ======
#  processing 101/494 files
#
# ======
#  processing 102/494 files
#
# ======
#  processing 103/494 files
#
# ======
#  processing 104/494 files
#
# ======
#  processing 105/494 files
#
# ======
#  processing 106/494 files
#
# ======
#  processing 107/494 files
#
# ======
#  processing 108/494 files
#
# ======
#  processing 109/494 files
#
# ======
#  processing 110/494 files
#
# ======
#  processing 111/494 files
#
# ======
#  processing 112/494 files
#
# ======
#  processing 113/494 files
#
# ======
#  processing 114/494 files
#
# ======
#  processing 115/494 files
#
# ======
#  processing 116/494 files
#
# ======
#  processing 117/494 files
#
# ======
#  processing 118/494 files
#
# ======
#  processing 119/494 files
#
# ======
#  processing 120/494 files
#
# ======
#  processing 121/494 files
#
# ======
#  processing 122/494 files
#
# ======
#  processing 123/494 files
#
# ======
#  processing 124/494 files
#
# ======
#  processing 125/494 files
#
# ======
#  processing 126/494 files
#
# ======
#  processing 127/494 files
#
# ======
#  processing 128/494 files
#
# ======
#  processing 129/494 files
#
# ======
#  processing 130/494 files
#
# ======
#  processing 131/494 files
#
# ======
#  processing 132/494 files
#
# ======
#  processing 133/494 files
#
# ======
#  processing 134/494 files
#
# ======
#  processing 135/494 files
#
# ======
#  processing 136/494 files
#
# ======
#  processing 137/494 files
#
# ======
#  processing 138/494 files
#
# ======
#  processing 139/494 files
#
# ======
#  processing 140/494 files
#
# ======
#  processing 141/494 files
#
# ======
#  processing 142/494 files
#
# ======
#  processing 143/494 files
#
# ======
#  processing 144/494 files
#
# ======
#  processing 145/494 files
#
# ======
#  processing 146/494 files
#
# ======
#  processing 147/494 files
#
# ======
#  processing 148/494 files
#
# ======
#  processing 149/494 files
#
# ======
#  processing 150/494 files
#
# ======
#  processing 151/494 files
#
# ======
#  processing 152/494 files
#
# ======
#  processing 153/494 files
#
# ======
#  processing 154/494 files
#
# ======
#  processing 155/494 files
#
# ======
#  processing 156/494 files
#
# ======
#  processing 157/494 files
#
# ======
#  processing 158/494 files
#
# ======
#  processing 159/494 files
#
# ======
#  processing 160/494 files
#
# ======
#  processing 161/494 files
#
# ======
#  processing 162/494 files
#
# ======
#  processing 163/494 files
#
# ======
#  processing 164/494 files
#
# ======
#  processing 165/494 files
#
# ======
#  processing 166/494 files
#
# ======
#  processing 167/494 files
#
# ======
#  processing 168/494 files
#
# ======
#  processing 169/494 files
#
# ======
#  processing 170/494 files
#
# ======
#  processing 171/494 files
#
# ======
#  processing 172/494 files
#
# ======
#  processing 173/494 files
#
# ======
#  processing 174/494 files
#
# ======
#  processing 175/494 files
#
# ======
#  processing 176/494 files
#
# ======
#  processing 177/494 files
#
# ======
#  processing 178/494 files
#
# ======
#  processing 179/494 files
#
# ======
#  processing 180/494 files
#
# ======
#  processing 181/494 files
#
# ======
#  processing 182/494 files
#
# ======
#  processing 183/494 files
#
# ======
#  processing 184/494 files
#
# ======
#  processing 185/494 files
#
# ======
#  processing 186/494 files
#
# ======
#  processing 187/494 files
#
# ======
#  processing 188/494 files
#
# ======
#  processing 189/494 files
#
# ======
#  processing 190/494 files
#
# ======
#  processing 191/494 files
#
# ======
#  processing 192/494 files
#
# ======
#  processing 193/494 files
#
# ======
#  processing 194/494 files
#
# ======
#  processing 195/494 files
#
# ======
#  processing 196/494 files
#
# ======
#  processing 197/494 files
#
# ======
#  processing 198/494 files
#
# ======
#  processing 199/494 files
#
# ======
#  processing 200/494 files
#
# ======
#  processing 201/494 files
#
# ======
#  processing 202/494 files
#
# ======
#  processing 203/494 files
#
# ======
#  processing 204/494 files
#
# ======
#  processing 205/494 files
#
# ======
#  processing 206/494 files
#
# ======
#  processing 207/494 files
#
# ======
#  processing 208/494 files
#
# ======
#  processing 209/494 files
#
# ======
#  processing 210/494 files
#
# ======
#  processing 211/494 files
#
# ======
#  processing 212/494 files
#
# ======
#  processing 213/494 files
#
# ======
#  processing 214/494 files
#
# ======
#  processing 215/494 files
#
# ======
#  processing 216/494 files
#
# ======
#  processing 217/494 files
#
# ======
#  processing 218/494 files
#
# ======
#  processing 219/494 files
#
# ======
#  processing 220/494 files
#
# ======
#  processing 221/494 files
#
# ======
#  processing 222/494 files
#
# ======
#  processing 223/494 files
#
# ======
#  processing 224/494 files
#
# ======
#  processing 225/494 files
#
# ======
#  processing 226/494 files
#
# ======
#  processing 227/494 files
#
# ======
#  processing 228/494 files
#
# ======
#  processing 229/494 files
#
# ======
#  processing 230/494 files
#
# ======
#  processing 231/494 files
#
# ======
#  processing 232/494 files
#
# ======
#  processing 233/494 files
#
# ======
#  processing 234/494 files
#
# ======
#  processing 235/494 files
#
# ======
#  processing 236/494 files
#
# ======
#  processing 237/494 files
#
# ======
#  processing 238/494 files
#
# ======
#  processing 239/494 files
#
# ======
#  processing 240/494 files
#
# ======
#  processing 241/494 files
#
# ======
#  processing 242/494 files
#
# ======
#  processing 243/494 files
#
# ======
#  processing 244/494 files
#
# ======
#  processing 245/494 files
#
# ======
#  processing 246/494 files
#
# ======
#  processing 247/494 files
#
# ======
#  processing 248/494 files
#
# ======
#  processing 249/494 files
#
# ======
#  processing 250/494 files
#
# ======
#  processing 251/494 files
#
# ======
#  processing 252/494 files
#
# ======
#  processing 253/494 files
#
# ======
#  processing 254/494 files
#
# ======
#  processing 255/494 files
#
# ======
#  processing 256/494 files
#
# ======
#  processing 257/494 files
#
# ======
#  processing 258/494 files
#
# ======
#  processing 259/494 files
#
# ======
#  processing 260/494 files
#
# ======
#  processing 261/494 files
#
# ======
#  processing 262/494 files
#
# ======
#  processing 263/494 files
#
# ======
#  processing 264/494 files
#
# ======
#  processing 265/494 files
#
# ======
#  processing 266/494 files
#
# ======
#  processing 267/494 files
#
# ======
#  processing 268/494 files
#
# ======
#  processing 269/494 files
#
# ======
#  processing 270/494 files
#
# ======
#  processing 271/494 files
#
# ======
#  processing 272/494 files
#
# ======
#  processing 273/494 files
#
# ======
#  processing 274/494 files
#
# ======
#  processing 275/494 files
#
# ======
#  processing 276/494 files
#
# ======
#  processing 277/494 files
#
# ======
#  processing 278/494 files
#
# ======
#  processing 279/494 files
#
# ======
#  processing 280/494 files
#
# ======
#  processing 281/494 files
#
# ======
#  processing 282/494 files
#
# ======
#  processing 283/494 files
#
# ======
#  processing 284/494 files
#
# ======
#  processing 285/494 files
#
# ======
#  processing 286/494 files
#
# ======
#  processing 287/494 files
#
# ======
#  processing 288/494 files
#
# ======
#  processing 289/494 files
#
# ======
#  processing 290/494 files
#
# ======
#  processing 291/494 files
#
# ======
#  processing 292/494 files
#
# ======
#  processing 293/494 files
#
# ======
#  processing 294/494 files
#
# ======
#  processing 295/494 files
#
# ======
#  processing 296/494 files
#
# ======
#  processing 297/494 files
#
# ======
#  processing 298/494 files
#
# ======
#  processing 299/494 files
#
# ======
#  processing 300/494 files
#
# ======
#  processing 301/494 files
#
# ======
#  processing 302/494 files
#
# ======
#  processing 303/494 files
#
# ======
#  processing 304/494 files
#
# ======
#  processing 305/494 files
#
# ======
#  processing 306/494 files
#
# ======
#  processing 307/494 files
#
# ======
#  processing 308/494 files
#
# ======
#  processing 309/494 files
#
# ======
#  processing 310/494 files
#
# ======
#  processing 311/494 files
#
# ======
#  processing 312/494 files
#
# ======
#  processing 313/494 files
#
# ======
#  processing 314/494 files
#
# ======
#  processing 315/494 files
#
# ======
#  processing 316/494 files
#
# ======
#  processing 317/494 files
#
# ======
#  processing 318/494 files
#
# ======
#  processing 319/494 files
#
# ======
#  processing 320/494 files
#
# ======
#  processing 321/494 files
#
# ======
#  processing 322/494 files
#
# ======
#  processing 323/494 files
#
# ======
#  processing 324/494 files
#
# ======
#  processing 325/494 files
#
# ======
#  processing 326/494 files
#
# ======
#  processing 327/494 files
#
# ======
#  processing 328/494 files
#
# ======
#  processing 329/494 files
#
# ======
#  processing 330/494 files
#
# ======
#  processing 331/494 files
#
# ======
#  processing 332/494 files
#
# ======
#  processing 333/494 files
#
# ======
#  processing 334/494 files
#
# ======
#  processing 335/494 files
#
# ======
#  processing 336/494 files
#
# ======
#  processing 337/494 files
#
# ======
#  processing 338/494 files
#
# ======
#  processing 339/494 files
#
# ======
#  processing 340/494 files
#
# ======
#  processing 341/494 files
#
# ======
#  processing 342/494 files
#
# ======
#  processing 343/494 files
#
# ======
#  processing 344/494 files
#
# ======
#  processing 345/494 files
#
# ======
#  processing 346/494 files
#
# ======
#  processing 347/494 files
#
# ======
#  processing 348/494 files
#
# ======
#  processing 349/494 files
#
# ======
#  processing 350/494 files
#
# ======
#  processing 351/494 files
#
# ======
#  processing 352/494 files
#
# ======
#  processing 353/494 files
#
# ======
#  processing 354/494 files
#
# ======
#  processing 355/494 files
#
# ======
#  processing 356/494 files
#
# ======
#  processing 357/494 files
#
# ======
#  processing 358/494 files
#
# ======
#  processing 359/494 files
#
# ======
#  processing 360/494 files
#
# ======
#  processing 361/494 files
#
# ======
#  processing 362/494 files
#
# ======
#  processing 363/494 files
#
# ======
#  processing 364/494 files
#
# ======
#  processing 365/494 files
#
# ======
#  processing 366/494 files
#
# ======
#  processing 367/494 files
#
# ======
#  processing 368/494 files
#
# ======
#  processing 369/494 files
#
# ======
#  processing 370/494 files
#
# ======
#  processing 371/494 files
#
# ======
#  processing 372/494 files
#
# ======
#  processing 373/494 files
#
# ======
#  processing 374/494 files
#
# ======
#  processing 375/494 files
#
# ======
#  processing 376/494 files
#
# ======
#  processing 377/494 files
#
# ======
#  processing 378/494 files
#
# ======
#  processing 379/494 files
#
# ======
#  processing 380/494 files
#
# ======
#  processing 381/494 files
#
# ======
#  processing 382/494 files
#
# ======
#  processing 383/494 files
#
# ======
#  processing 384/494 files
#
# ======
#  processing 385/494 files
#
# ======
#  processing 386/494 files
#
# ======
#  processing 387/494 files
#
# ======
#  processing 388/494 files
#
# ======
#  processing 389/494 files
#
# ======
#  processing 390/494 files
#
# ======
#  processing 391/494 files
#
# ======
#  processing 392/494 files
#
# ======
#  processing 393/494 files
#
# ======
#  processing 394/494 files
#
# ======
#  processing 395/494 files
#
# ======
#  processing 396/494 files
#
# ======
#  processing 397/494 files
#
# ======
#  processing 398/494 files
#
# ======
#  processing 399/494 files
#
# ======
#  processing 400/494 files
#
# ======
#  processing 401/494 files
#
# ======
#  processing 402/494 files
#
# ======
#  processing 403/494 files
#
# ======
#  processing 404/494 files
#
# ======
#  processing 405/494 files
#
# ======
#  processing 406/494 files
#
# ======
#  processing 407/494 files
#
# ======
#  processing 408/494 files
#
# ======
#  processing 409/494 files
#
# ======
#  processing 410/494 files
#
# ======
#  processing 411/494 files
#
# ======
#  processing 412/494 files
#
# ======
#  processing 413/494 files
#
# ======
#  processing 414/494 files
#
# ======
#  processing 415/494 files
#
# ======
#  processing 416/494 files
#
# ======
#  processing 417/494 files
#
# ======
#  processing 418/494 files
#
# ======
#  processing 419/494 files
#
# ======
#  processing 420/494 files
#
# ======
#  processing 421/494 files
#
# ======
#  processing 422/494 files
#
# ======
#  processing 423/494 files
#
# ======
#  processing 424/494 files
#
# ======
#  processing 425/494 files
#
# ======
#  processing 426/494 files
#
# ======
#  processing 427/494 files
#
# ======
#  processing 428/494 files
#
# ======
#  processing 429/494 files
#
# ======
#  processing 430/494 files
#
# ======
#  processing 431/494 files
#
# ======
#  processing 432/494 files
#
# ======
#  processing 433/494 files
#
# ======
#  processing 434/494 files
#
# ======
#  processing 435/494 files
#
# ======
#  processing 436/494 files
#
# ======
#  processing 437/494 files
#
# ======
#  processing 438/494 files
#
# ======
#  processing 439/494 files
#
# ======
#  processing 440/494 files
#
# ======
#  processing 441/494 files
#
# ======
#  processing 442/494 files
#
# ======
#  processing 443/494 files
#
# ======
#  processing 444/494 files
#
# ======
#  processing 445/494 files
#
# ======
#  processing 446/494 files
#
# ======
#  processing 447/494 files
#
# ======
#  processing 448/494 files
#
# ======
#  processing 449/494 files
#
# ======
#  processing 450/494 files
#
# ======
#  processing 451/494 files
#
# ======
#  processing 452/494 files
#
# ======
#  processing 453/494 files
#
# ======
#  processing 454/494 files
#
# ======
#  processing 455/494 files
#
# ======
#  processing 456/494 files
#
# ======
#  processing 457/494 files
#
# ======
#  processing 458/494 files
#
# ======
#  processing 459/494 files
#
# ======
#  processing 460/494 files
#
# ======
#  processing 461/494 files
#
# ======
#  processing 462/494 files
#
# ======
#  processing 463/494 files
#
# ======
#  processing 464/494 files
#
# ======
#  processing 465/494 files
#
# ======
#  processing 466/494 files
#
# ======
#  processing 467/494 files
#
# ======
#  processing 468/494 files
#
# ======
#  processing 469/494 files
#
# ======
#  processing 470/494 files
#
# ======
#  processing 471/494 files
#
# ======
#  processing 472/494 files
#
# ======
#  processing 473/494 files
#
# ======
#  processing 474/494 files
#
# ======
#  processing 475/494 files
#
# ======
#  processing 476/494 files
#
# ======
#  processing 477/494 files
#
# ======
#  processing 478/494 files
#
# ======
#  processing 479/494 files
#
# ======
#  processing 480/494 files
#
# ======
#  processing 481/494 files
#
# ======
#  processing 482/494 files
#
# ======
#  processing 483/494 files
#
# ======
#  processing 484/494 files
#
# ======
#  processing 485/494 files
#
# ======
#  processing 486/494 files
#
# ======
#  processing 487/494 files
#
# ======
#  processing 488/494 files
#
# ======
#  processing 489/494 files
#
# ======
#  processing 490/494 files
#
# ======
#  processing 491/494 files
#
# ======
#  processing 492/494 files
#
# ======
#  processing 493/494 files
#
# ======
#  processing 494/494 files
#
# processing batch 0 of size 100
# processing batch 1 of size 100
# processing batch 2 of size 100
# processing batch 3 of size 100
# processing batch 4 of size 100

# %%
eval_responses(gpt_4_responses, 'answer', role_response_dr_answers)
# Out:
# # correct = 216 / 494
# 0.43724696356275305

# %% [markdown]
# Hmm so performance went down on adding the role and responsibility - I want to look at some of the "incorrect" answers to see why

# %%
incorrect = get_incorrect(gpt_4_responses, 'answer', role_response_dr_answers)
incorrect
# Out:
# /var/folders/bq/0x2c77dd791b4v2h4vx5j1_40000gn/T/ipykernel_49004/4293578304.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   incorrect_df['llm_responses'] = incorrect_llm_responses
#                                               question  \
# 0    Two weeks after undergoing an emergency cardia...
# 1    A 46-year-old man is brought to the emergency ...
# 2    A 30-year-old African American woman comes to ...
# 5    A 55-year-old man comes to the physician becau...
# 6    A 56-year-old man with a history of hypertensi...
# ..                                                 ...
# 486  A 78-year-old man is brought to the emergency ...
# 490  A previously healthy 21-year-old man comes to ...
# 491  A 15-year-old boy is brought to the physician ...
# 492  A 9-year-old boy is brought to a pediatric psy...
# 493  A 28-year-old woman is brought to the emergenc...
#
#                                            answer  \
# 0                        Cholesterol embolization
# 1                     Benzodiazepine intoxication
# 2                Histoplasma capsulatum infection
# 5                 Femoropopliteal artery stenosis
# 6                              Aldosterone excess
# ..                                            ...
# 486  Occlusion of the left middle cerebral artery
# 490                      Chronic cerebral hypoxia
# 491                             Kallmann syndrome
# 492      Attention deficit hyperactivity disorder
# 493                             Bronchial rupture
#
#                                          llm_responses
# 0    To evaluate this 61-year-old man with decrease...
# 1    To evaluate this patient effectively, let's fo...
# 2    To evaluate the symptoms and make a differenti...
# 5    To identify the most likely diagnosis in this ...
# 6    To analyze this case of the 56-year-old man, w...
# ..                                                 ...
# 486  To determine the most likely cause of this 78-...
# 490  To arrive at a diagnosis for this 21-year-old ...
# 491  To determine the most likely diagnosis for thi...
# 492  To arrive at a diagnosis for this 9-year-old b...
# 493  To arrive at the most likely diagnosis in this...
#
# [278 rows x 3 columns]

# %%
print(role_response_dr_answers[2])
# Out:
# To evaluate the symptoms and make a differential diagnosis for this 30-year-old African American woman, we can begin breaking down key elements of her presentation:
#
# ### Step 1: Symptoms and History
# The patient has:
# 1. Dry cough
# 2. Chest discomfort
# 3. Headaches, muscle aches, joint pain, fever, and chills
# 4. A recent history of hiking in Mississippi, which could expose her to certain environmental pathogens.
# 5. A background of asthma, which may predispose her to respiratory complications.
#
# ### Step 2: Examination Findings
# - Slight wheezes throughout both lung fields which suggest potential bronchospasm or irritation in the lungs.
# - Positive results for polysaccharide antigens, which can indicate a fungal infection.
# - Bronchoalveolar lavage shows macrophages filled with a dimorphic fungus with septate hyphae.
#
# ### Step 3: Key Laboratory Finding
# The presence of a dimorphic fungus with septate hyphae, combined with the environmental exposure (hiking in Mississippi), suggests a likely infection with a fungus endemic to that region. Endemic fungi typically implicated in pulmonary infections from specific geographic areas include:
#
# - **Histoplasma capsulatum**: Common in the Mississippi River Valley. It is dimorphic and can cause respiratory illness, particularly in individuals with compromised respiratory function (e.g., asthma).
# - **Coccidioides immitis**: More common in the southwestern U.S. and would be less likely given the history of exposure in Mississippi.
# - **Blastomyces dermatitidis**: Can also occur in certain regions, but less commonly than Histoplasma.
#
# ### Step 4: Evaluating the Information
# - The chest symptoms, systemic symptoms (fever, chills, myalgias), and specific findings from bronchoalveolar lavage fit with an infection by **Histoplasma capsulatum**. The “dimorphic fungus with septate hyphae” is typically associated with this type of fungal infection.
#
# ### Conclusion
# Given the geographic exposure to Mississippi, the clinical symptoms, and the specific laboratory findings of a dimorphic fungus observed in the bronchoalveolar lavage (likely reflecting Histoplasma infection), the most likely cause of this patient’s symptoms is an infection with **Histoplasma capsulatum**.
#
# ### Final Diagnosis
# The most likely cause of this patient's symptoms is **Histoplasma capsulatum** infection.

# %% [markdown]
# ### so you can see above that really the correct answer is in there, it's just not an *exact* substring - could this be solved with some ....... **Structured output**????

# %%
from lib.llms.chats.openai import StructuredOutputChatOpenAI
from pydantic import BaseModel


class DiagnosesModel(BaseModel):
    chain_of_thought: str
    possible_diagnoses: list[str]
    final_diagnoses: str

structured_llm = StructuredOutputChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o-mini',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4,
    response_schema=DiagnosesModel
)

# %%
structured_role_response_dr_answers, need_reprocess = await async_answer(structured_llm, questions, role_response_template, batch_size = 100)
# Out:
# ======
#  processing 1/494 files
#
# ======
#  processing 2/494 files
#
# ======
#  processing 3/494 files
#
# ======
#  processing 4/494 files
#
# ======
#  processing 5/494 files
#
# ======
#  processing 6/494 files
#
# ======
#  processing 7/494 files
#
# ======
#  processing 8/494 files
#
# ======
#  processing 9/494 files
#
# ======
#  processing 10/494 files
#
# ======
#  processing 11/494 files
#
# ======
#  processing 12/494 files
#
# ======
#  processing 13/494 files
#
# ======
#  processing 14/494 files
#
# ======
#  processing 15/494 files
#
# ======
#  processing 16/494 files
#
# ======
#  processing 17/494 files
#
# ======
#  processing 18/494 files
#
# ======
#  processing 19/494 files
#
# ======
#  processing 20/494 files
#
# ======
#  processing 21/494 files
#
# ======
#  processing 22/494 files
#
# ======
#  processing 23/494 files
#
# ======
#  processing 24/494 files
#
# ======
#  processing 25/494 files
#
# ======
#  processing 26/494 files
#
# ======
#  processing 27/494 files
#
# ======
#  processing 28/494 files
#
# ======
#  processing 29/494 files
#
# ======
#  processing 30/494 files
#
# ======
#  processing 31/494 files
#
# ======
#  processing 32/494 files
#
# ======
#  processing 33/494 files
#
# ======
#  processing 34/494 files
#
# ======
#  processing 35/494 files
#
# ======
#  processing 36/494 files
#
# ======
#  processing 37/494 files
#
# ======
#  processing 38/494 files
#
# ======
#  processing 39/494 files
#
# ======
#  processing 40/494 files
#
# ======
#  processing 41/494 files
#
# ======
#  processing 42/494 files
#
# ======
#  processing 43/494 files
#
# ======
#  processing 44/494 files
#
# ======
#  processing 45/494 files
#
# ======
#  processing 46/494 files
#
# ======
#  processing 47/494 files
#
# ======
#  processing 48/494 files
#
# ======
#  processing 49/494 files
#
# ======
#  processing 50/494 files
#
# ======
#  processing 51/494 files
#
# ======
#  processing 52/494 files
#
# ======
#  processing 53/494 files
#
# ======
#  processing 54/494 files
#
# ======
#  processing 55/494 files
#
# ======
#  processing 56/494 files
#
# ======
#  processing 57/494 files
#
# ======
#  processing 58/494 files
#
# ======
#  processing 59/494 files
#
# ======
#  processing 60/494 files
#
# ======
#  processing 61/494 files
#
# ======
#  processing 62/494 files
#
# ======
#  processing 63/494 files
#
# ======
#  processing 64/494 files
#
# ======
#  processing 65/494 files
#
# ======
#  processing 66/494 files
#
# ======
#  processing 67/494 files
#
# ======
#  processing 68/494 files
#
# ======
#  processing 69/494 files
#
# ======
#  processing 70/494 files
#
# ======
#  processing 71/494 files
#
# ======
#  processing 72/494 files
#
# ======
#  processing 73/494 files
#
# ======
#  processing 74/494 files
#
# ======
#  processing 75/494 files
#
# ======
#  processing 76/494 files
#
# ======
#  processing 77/494 files
#
# ======
#  processing 78/494 files
#
# ======
#  processing 79/494 files
#
# ======
#  processing 80/494 files
#
# ======
#  processing 81/494 files
#
# ======
#  processing 82/494 files
#
# ======
#  processing 83/494 files
#
# ======
#  processing 84/494 files
#
# ======
#  processing 85/494 files
#
# ======
#  processing 86/494 files
#
# ======
#  processing 87/494 files
#
# ======
#  processing 88/494 files
#
# ======
#  processing 89/494 files
#
# ======
#  processing 90/494 files
#
# ======
#  processing 91/494 files
#
# ======
#  processing 92/494 files
#
# ======
#  processing 93/494 files
#
# ======
#  processing 94/494 files
#
# ======
#  processing 95/494 files
#
# ======
#  processing 96/494 files
#
# ======
#  processing 97/494 files
#
# ======
#  processing 98/494 files
#
# ======
#  processing 99/494 files
#
# ======
#  processing 100/494 files
#
# ======
#  processing 101/494 files
#
# ======
#  processing 102/494 files
#
# ======
#  processing 103/494 files
#
# ======
#  processing 104/494 files
#
# ======
#  processing 105/494 files
#
# ======
#  processing 106/494 files
#
# ======
#  processing 107/494 files
#
# ======
#  processing 108/494 files
#
# ======
#  processing 109/494 files
#
# ======
#  processing 110/494 files
#
# ======
#  processing 111/494 files
#
# ======
#  processing 112/494 files
#
# ======
#  processing 113/494 files
#
# ======
#  processing 114/494 files
#
# ======
#  processing 115/494 files
#
# ======
#  processing 116/494 files
#
# ======
#  processing 117/494 files
#
# ======
#  processing 118/494 files
#
# ======
#  processing 119/494 files
#
# ======
#  processing 120/494 files
#
# ======
#  processing 121/494 files
#
# ======
#  processing 122/494 files
#
# ======
#  processing 123/494 files
#
# ======
#  processing 124/494 files
#
# ======
#  processing 125/494 files
#
# ======
#  processing 126/494 files
#
# ======
#  processing 127/494 files
#
# ======
#  processing 128/494 files
#
# ======
#  processing 129/494 files
#
# ======
#  processing 130/494 files
#
# ======
#  processing 131/494 files
#
# ======
#  processing 132/494 files
#
# ======
#  processing 133/494 files
#
# ======
#  processing 134/494 files
#
# ======
#  processing 135/494 files
#
# ======
#  processing 136/494 files
#
# ======
#  processing 137/494 files
#
# ======
#  processing 138/494 files
#
# ======
#  processing 139/494 files
#
# ======
#  processing 140/494 files
#
# ======
#  processing 141/494 files
#
# ======
#  processing 142/494 files
#
# ======
#  processing 143/494 files
#
# ======
#  processing 144/494 files
#
# ======
#  processing 145/494 files
#
# ======
#  processing 146/494 files
#
# ======
#  processing 147/494 files
#
# ======
#  processing 148/494 files
#
# ======
#  processing 149/494 files
#
# ======
#  processing 150/494 files
#
# ======
#  processing 151/494 files
#
# ======
#  processing 152/494 files
#
# ======
#  processing 153/494 files
#
# ======
#  processing 154/494 files
#
# ======
#  processing 155/494 files
#
# ======
#  processing 156/494 files
#
# ======
#  processing 157/494 files
#
# ======
#  processing 158/494 files
#
# ======
#  processing 159/494 files
#
# ======
#  processing 160/494 files
#
# ======
#  processing 161/494 files
#
# ======
#  processing 162/494 files
#
# ======
#  processing 163/494 files
#
# ======
#  processing 164/494 files
#
# ======
#  processing 165/494 files
#
# ======
#  processing 166/494 files
#
# ======
#  processing 167/494 files
#
# ======
#  processing 168/494 files
#
# ======
#  processing 169/494 files
#
# ======
#  processing 170/494 files
#
# ======
#  processing 171/494 files
#
# ======
#  processing 172/494 files
#
# ======
#  processing 173/494 files
#
# ======
#  processing 174/494 files
#
# ======
#  processing 175/494 files
#
# ======
#  processing 176/494 files
#
# ======
#  processing 177/494 files
#
# ======
#  processing 178/494 files
#
# ======
#  processing 179/494 files
#
# ======
#  processing 180/494 files
#
# ======
#  processing 181/494 files
#
# ======
#  processing 182/494 files
#
# ======
#  processing 183/494 files
#
# ======
#  processing 184/494 files
#
# ======
#  processing 185/494 files
#
# ======
#  processing 186/494 files
#
# ======
#  processing 187/494 files
#
# ======
#  processing 188/494 files
#
# ======
#  processing 189/494 files
#
# ======
#  processing 190/494 files
#
# ======
#  processing 191/494 files
#
# ======
#  processing 192/494 files
#
# ======
#  processing 193/494 files
#
# ======
#  processing 194/494 files
#
# ======
#  processing 195/494 files
#
# ======
#  processing 196/494 files
#
# ======
#  processing 197/494 files
#
# ======
#  processing 198/494 files
#
# ======
#  processing 199/494 files
#
# ======
#  processing 200/494 files
#
# ======
#  processing 201/494 files
#
# ======
#  processing 202/494 files
#
# ======
#  processing 203/494 files
#
# ======
#  processing 204/494 files
#
# ======
#  processing 205/494 files
#
# ======
#  processing 206/494 files
#
# ======
#  processing 207/494 files
#
# ======
#  processing 208/494 files
#
# ======
#  processing 209/494 files
#
# ======
#  processing 210/494 files
#
# ======
#  processing 211/494 files
#
# ======
#  processing 212/494 files
#
# ======
#  processing 213/494 files
#
# ======
#  processing 214/494 files
#
# ======
#  processing 215/494 files
#
# ======
#  processing 216/494 files
#
# ======
#  processing 217/494 files
#
# ======
#  processing 218/494 files
#
# ======
#  processing 219/494 files
#
# ======
#  processing 220/494 files
#
# ======
#  processing 221/494 files
#
# ======
#  processing 222/494 files
#
# ======
#  processing 223/494 files
#
# ======
#  processing 224/494 files
#
# ======
#  processing 225/494 files
#
# ======
#  processing 226/494 files
#
# ======
#  processing 227/494 files
#
# ======
#  processing 228/494 files
#
# ======
#  processing 229/494 files
#
# ======
#  processing 230/494 files
#
# ======
#  processing 231/494 files
#
# ======
#  processing 232/494 files
#
# ======
#  processing 233/494 files
#
# ======
#  processing 234/494 files
#
# ======
#  processing 235/494 files
#
# ======
#  processing 236/494 files
#
# ======
#  processing 237/494 files
#
# ======
#  processing 238/494 files
#
# ======
#  processing 239/494 files
#
# ======
#  processing 240/494 files
#
# ======
#  processing 241/494 files
#
# ======
#  processing 242/494 files
#
# ======
#  processing 243/494 files
#
# ======
#  processing 244/494 files
#
# ======
#  processing 245/494 files
#
# ======
#  processing 246/494 files
#
# ======
#  processing 247/494 files
#
# ======
#  processing 248/494 files
#
# ======
#  processing 249/494 files
#
# ======
#  processing 250/494 files
#
# ======
#  processing 251/494 files
#
# ======
#  processing 252/494 files
#
# ======
#  processing 253/494 files
#
# ======
#  processing 254/494 files
#
# ======
#  processing 255/494 files
#
# ======
#  processing 256/494 files
#
# ======
#  processing 257/494 files
#
# ======
#  processing 258/494 files
#
# ======
#  processing 259/494 files
#
# ======
#  processing 260/494 files
#
# ======
#  processing 261/494 files
#
# ======
#  processing 262/494 files
#
# ======
#  processing 263/494 files
#
# ======
#  processing 264/494 files
#
# ======
#  processing 265/494 files
#
# ======
#  processing 266/494 files
#
# ======
#  processing 267/494 files
#
# ======
#  processing 268/494 files
#
# ======
#  processing 269/494 files
#
# ======
#  processing 270/494 files
#
# ======
#  processing 271/494 files
#
# ======
#  processing 272/494 files
#
# ======
#  processing 273/494 files
#
# ======
#  processing 274/494 files
#
# ======
#  processing 275/494 files
#
# ======
#  processing 276/494 files
#
# ======
#  processing 277/494 files
#
# ======
#  processing 278/494 files
#
# ======
#  processing 279/494 files
#
# ======
#  processing 280/494 files
#
# ======
#  processing 281/494 files
#
# ======
#  processing 282/494 files
#
# ======
#  processing 283/494 files
#
# ======
#  processing 284/494 files
#
# ======
#  processing 285/494 files
#
# ======
#  processing 286/494 files
#
# ======
#  processing 287/494 files
#
# ======
#  processing 288/494 files
#
# ======
#  processing 289/494 files
#
# ======
#  processing 290/494 files
#
# ======
#  processing 291/494 files
#
# ======
#  processing 292/494 files
#
# ======
#  processing 293/494 files
#
# ======
#  processing 294/494 files
#
# ======
#  processing 295/494 files
#
# ======
#  processing 296/494 files
#
# ======
#  processing 297/494 files
#
# ======
#  processing 298/494 files
#
# ======
#  processing 299/494 files
#
# ======
#  processing 300/494 files
#
# ======
#  processing 301/494 files
#
# ======
#  processing 302/494 files
#
# ======
#  processing 303/494 files
#
# ======
#  processing 304/494 files
#
# ======
#  processing 305/494 files
#
# ======
#  processing 306/494 files
#
# ======
#  processing 307/494 files
#
# ======
#  processing 308/494 files
#
# ======
#  processing 309/494 files
#
# ======
#  processing 310/494 files
#
# ======
#  processing 311/494 files
#
# ======
#  processing 312/494 files
#
# ======
#  processing 313/494 files
#
# ======
#  processing 314/494 files
#
# ======
#  processing 315/494 files
#
# ======
#  processing 316/494 files
#
# ======
#  processing 317/494 files
#
# ======
#  processing 318/494 files
#
# ======
#  processing 319/494 files
#
# ======
#  processing 320/494 files
#
# ======
#  processing 321/494 files
#
# ======
#  processing 322/494 files
#
# ======
#  processing 323/494 files
#
# ======
#  processing 324/494 files
#
# ======
#  processing 325/494 files
#
# ======
#  processing 326/494 files
#
# ======
#  processing 327/494 files
#
# ======
#  processing 328/494 files
#
# ======
#  processing 329/494 files
#
# ======
#  processing 330/494 files
#
# ======
#  processing 331/494 files
#
# ======
#  processing 332/494 files
#
# ======
#  processing 333/494 files
#
# ======
#  processing 334/494 files
#
# ======
#  processing 335/494 files
#
# ======
#  processing 336/494 files
#
# ======
#  processing 337/494 files
#
# ======
#  processing 338/494 files
#
# ======
#  processing 339/494 files
#
# ======
#  processing 340/494 files
#
# ======
#  processing 341/494 files
#
# ======
#  processing 342/494 files
#
# ======
#  processing 343/494 files
#
# ======
#  processing 344/494 files
#
# ======
#  processing 345/494 files
#
# ======
#  processing 346/494 files
#
# ======
#  processing 347/494 files
#
# ======
#  processing 348/494 files
#
# ======
#  processing 349/494 files
#
# ======
#  processing 350/494 files
#
# ======
#  processing 351/494 files
#
# ======
#  processing 352/494 files
#
# ======
#  processing 353/494 files
#
# ======
#  processing 354/494 files
#
# ======
#  processing 355/494 files
#
# ======
#  processing 356/494 files
#
# ======
#  processing 357/494 files
#
# ======
#  processing 358/494 files
#
# ======
#  processing 359/494 files
#
# ======
#  processing 360/494 files
#
# ======
#  processing 361/494 files
#
# ======
#  processing 362/494 files
#
# ======
#  processing 363/494 files
#
# ======
#  processing 364/494 files
#
# ======
#  processing 365/494 files
#
# ======
#  processing 366/494 files
#
# ======
#  processing 367/494 files
#
# ======
#  processing 368/494 files
#
# ======
#  processing 369/494 files
#
# ======
#  processing 370/494 files
#
# ======
#  processing 371/494 files
#
# ======
#  processing 372/494 files
#
# ======
#  processing 373/494 files
#
# ======
#  processing 374/494 files
#
# ======
#  processing 375/494 files
#
# ======
#  processing 376/494 files
#
# ======
#  processing 377/494 files
#
# ======
#  processing 378/494 files
#
# ======
#  processing 379/494 files
#
# ======
#  processing 380/494 files
#
# ======
#  processing 381/494 files
#
# ======
#  processing 382/494 files
#
# ======
#  processing 383/494 files
#
# ======
#  processing 384/494 files
#
# ======
#  processing 385/494 files
#
# ======
#  processing 386/494 files
#
# ======
#  processing 387/494 files
#
# ======
#  processing 388/494 files
#
# ======
#  processing 389/494 files
#
# ======
#  processing 390/494 files
#
# ======
#  processing 391/494 files
#
# ======
#  processing 392/494 files
#
# ======
#  processing 393/494 files
#
# ======
#  processing 394/494 files
#
# ======
#  processing 395/494 files
#
# ======
#  processing 396/494 files
#
# ======
#  processing 397/494 files
#
# ======
#  processing 398/494 files
#
# ======
#  processing 399/494 files
#
# ======
#  processing 400/494 files
#
# ======
#  processing 401/494 files
#
# ======
#  processing 402/494 files
#
# ======
#  processing 403/494 files
#
# ======
#  processing 404/494 files
#
# ======
#  processing 405/494 files
#
# ======
#  processing 406/494 files
#
# ======
#  processing 407/494 files
#
# ======
#  processing 408/494 files
#
# ======
#  processing 409/494 files
#
# ======
#  processing 410/494 files
#
# ======
#  processing 411/494 files
#
# ======
#  processing 412/494 files
#
# ======
#  processing 413/494 files
#
# ======
#  processing 414/494 files
#
# ======
#  processing 415/494 files
#
# ======
#  processing 416/494 files
#
# ======
#  processing 417/494 files
#
# ======
#  processing 418/494 files
#
# ======
#  processing 419/494 files
#
# ======
#  processing 420/494 files
#
# ======
#  processing 421/494 files
#
# ======
#  processing 422/494 files
#
# ======
#  processing 423/494 files
#
# ======
#  processing 424/494 files
#
# ======
#  processing 425/494 files
#
# ======
#  processing 426/494 files
#
# ======
#  processing 427/494 files
#
# ======
#  processing 428/494 files
#
# ======
#  processing 429/494 files
#
# ======
#  processing 430/494 files
#
# ======
#  processing 431/494 files
#
# ======
#  processing 432/494 files
#
# ======
#  processing 433/494 files
#
# ======
#  processing 434/494 files
#
# ======
#  processing 435/494 files
#
# ======
#  processing 436/494 files
#
# ======
#  processing 437/494 files
#
# ======
#  processing 438/494 files
#
# ======
#  processing 439/494 files
#
# ======
#  processing 440/494 files
#
# ======
#  processing 441/494 files
#
# ======
#  processing 442/494 files
#
# ======
#  processing 443/494 files
#
# ======
#  processing 444/494 files
#
# ======
#  processing 445/494 files
#
# ======
#  processing 446/494 files
#
# ======
#  processing 447/494 files
#
# ======
#  processing 448/494 files
#
# ======
#  processing 449/494 files
#
# ======
#  processing 450/494 files
#
# ======
#  processing 451/494 files
#
# ======
#  processing 452/494 files
#
# ======
#  processing 453/494 files
#
# ======
#  processing 454/494 files
#
# ======
#  processing 455/494 files
#
# ======
#  processing 456/494 files
#
# ======
#  processing 457/494 files
#
# ======
#  processing 458/494 files
#
# ======
#  processing 459/494 files
#
# ======
#  processing 460/494 files
#
# ======
#  processing 461/494 files
#
# ======
#  processing 462/494 files
#
# ======
#  processing 463/494 files
#
# ======
#  processing 464/494 files
#
# ======
#  processing 465/494 files
#
# ======
#  processing 466/494 files
#
# ======
#  processing 467/494 files
#
# ======
#  processing 468/494 files
#
# ======
#  processing 469/494 files
#
# ======
#  processing 470/494 files
#
# ======
#  processing 471/494 files
#
# ======
#  processing 472/494 files
#
# ======
#  processing 473/494 files
#
# ======
#  processing 474/494 files
#
# ======
#  processing 475/494 files
#
# ======
#  processing 476/494 files
#
# ======
#  processing 477/494 files
#
# ======
#  processing 478/494 files
#
# ======
#  processing 479/494 files
#
# ======
#  processing 480/494 files
#
# ======
#  processing 481/494 files
#
# ======
#  processing 482/494 files
#
# ======
#  processing 483/494 files
#
# ======
#  processing 484/494 files
#
# ======
#  processing 485/494 files
#
# ======
#  processing 486/494 files
#
# ======
#  processing 487/494 files
#
# ======
#  processing 488/494 files
#
# ======
#  processing 489/494 files
#
# ======
#  processing 490/494 files
#
# ======
#  processing 491/494 files
#
# ======
#  processing 492/494 files
#
# ======
#  processing 493/494 files
#
# ======
#  processing 494/494 files
#
# processing batch 0 of size 100
# processing batch 1 of size 100
# processing batch 2 of size 100
# processing batch 3 of size 100
# processing batch 4 of size 100

# %%
print(structured_role_response_dr_answers[0]['final_diagnoses'])
# Out:
# Thrombotic Thrombocytopenic Purpura (TTP)

# %%
from pprint import pprint
pprint(structured_role_response_dr_answers[0])
# Out:
# {'chain_of_thought': '1. **Patient History:** The patient recently underwent '
#                      'cardiac catheterization and stenting for unstable '
#                      'angina. This procedure, while often necessary, is '
#                      'associated with some risks, including renal '
#                      'complications, particularly in patients with existing '
#                      'risk factors such as diabetes mellitus.\n'
#                      '\n'
#                      '2. **Symptoms:** The symptoms of decreased urinary '
#                      'output and malaise occurring two weeks post-procedure, '
#                      'alongside a fever (38°C), indicate a possible issue that '
#                      'may arise following this procedure. The mottled, '
#                      'reticulated purplish discoloration noted in the feet '
#                      'suggests possible vascular or circulatory impairment.\n'
#                      '\n'
#                      '3. **Laboratory Findings:** The laboratory studies '
#                      'show:\n'
#                      '   - Elevated serum urea nitrogen (25 mg/dL) and '
#                      'creatinine (4.2 mg/dL), indicating acute kidney injury '
#                      '(AKI). This is concerning especially given that the '
#                      'baseline kidney function in diabetics can be '
#                      'compromised.\n'
#                      '   - Elevated leukocyte count (16,400/mm3) with a left '
#                      'shift (increased segmented neutrophils and eosinophils), '
#                      'suggesting a response to infection or inflammatory '
#                      'state.\n'
#                      '   - Significantly elevated erythrocyte sedimentation '
#                      'rate (68 mm/h), indicating high levels of inflammation.\n'
#                      '  \n'
#                      '4. **Renal Biopsy Findings:** The renal biopsy shows '
#                      'intravascular spindle-shaped vacuoles. This finding is '
#                      'characteristic of a specific type of renal pathology.\n'
#                      '\n'
#                      '5. **Differential Diagnosis Consideration:**  The '
#                      'combination of AKI, fever, malaise, and the biopsy '
#                      'findings leads us to consider several differential '
#                      'diagnoses:\n'
#                      '   - **Contrast-Induced Nephropathy:** This often occurs '
#                      'after invasive procedures involving contrast media; '
#                      'however, it does not explain the systemic symptoms '
#                      '(fever, malaise, reticulated discoloration). \n'
#                      '   - **Acute Interstitial Nephritis (AIN):** Commonly '
#                      'due to drug reactions (e.g. NSAIDs) or infections; '
#                      'characterized by eosinophilia, which we do observe, but '
#                      'the presence of intravascular vacuoles is not typical.\n'
#                      '   - **Renal Vasculitis or Thrombotic Microangiopathy:** '
#                      'This could explain both the renal failure and the '
#                      'discoloration of the extremities. The presence of '
#                      'eosinophils may also align here with certain types of '
#                      'vasculitis.\n'
#                      '   - **Thrombotic Thrombocytopenic Purpura (TTP):** This '
#                      'fits the description with acute renal failure, a '
#                      'suitable clinical setting (recent catheterization), as '
#                      'well as the appearance of the feet.\n'
#                      '   - **Sepsis/Infection:** Given the leukocytosis and '
#                      'fever; however, the renal biopsy findings do not '
#                      'strongly correlate with a typical infectious process.\n'
#                      '\n'
#                      '6. **Final Diagnosis Deduction:** Among all the '
#                      'possibilities, the **intravascular spindle-shaped '
#                      'vacuoles** noted in the renal biopsy is particularly '
#                      'indicative of a condition known as **Thrombotic '
#                      'Thrombocytopenic Purpura (TTP)**, which is characterized '
#                      'by microangiopathic hemolytic anemia, thrombocytopenia, '
#                      'renal failure, and neurological manifestations often '
#                      'precipitated by recent medical procedures or '
#                      'infections.\n'
#                      '\n'
#                      "Thus, the most likely cause of this patient's symptoms "
#                      'is **Thrombotic Thrombocytopenic Purpura (TTP)** due to '
#                      'the post-procedural timing and the specific pathological '
#                      'findings noted in the renal biopsy. \n',
#  'final_diagnoses': 'Thrombotic Thrombocytopenic Purpura (TTP)',
#  'possible_diagnoses': ['Contrast-Induced Nephropathy',
#                         'Acute Interstitial Nephritis (AIN)',
#                         'Renal Vasculitis',
#                         'Thrombotic Thrombocytopenic Purpura (TTP)',
#                         'Sepsis/Infection']}

# %%
eval_responses(gpt_4_responses, 'answer', [ob['final_diagnoses'] for ob in structured_role_response_dr_answers])
# Out:
# # correct = 157 / 494
# 0.31781376518218624

# %% [markdown]
# #### lol no that made it worse.....
#
#
# I'm going to start going off script here and see what I can do with some explicit diagnostic steps

# %%
diagnostic_template = PromptTemplate("""
You are an experienced medical diagnostician AI. Your task is to accurately diagnose a medical condition or sickness based on patient symptoms and laboratory data. You will use deductive reasoning from a differential diagnosis to rule out unlikely diagnoses and arrive at the correct one.

First, review the patient case:
<patient_case>
{question}
</patient_case>

To diagnose the patient's condition, follow these steps:

1. Create a list of potential diagnoses (differential diagnosis) based on the presented case.

2. For each potential diagnosis in your list:
   a. Evaluate how well it matches the patient's symptoms and lab results.
   b. Consider any inconsistencies or contradictions between the diagnosis and the available information.
   c. Assess the likelihood of the diagnosis based on prevalence and patient demographics (if available).

3. Rule out unlikely diagnoses by explaining why they don't fit the patient's presentation.

4. Narrow down your list to the most probable diagnosis or diagnoses.

5. If multiple diagnoses remain plausible, rank them in order of likelihood.

6. Provide a final diagnosis (or top differential diagnoses if a single diagnosis cannot be determined with high confidence).

7. Explain your reasoning for the final diagnosis, including:
   a. How it accounts for the patient's symptoms and lab results.
   b. Why it is more likely than the other potential diagnoses you considered.
   c. Any additional tests or information that could help confirm the diagnosis.

Present your analysis and final diagnosis in the following format:

differential_diagnosis: List your initial differential diagnosis here, with brief explanations for each potential condition.

ruled_out_diagnoses: Explain which diagnoses you ruled out and why, based on the available information.

final_diagnosis: State your final diagnosis (or top differential diagnoses if a single diagnosis cannot be determined with high confidence).

explanation: Provide a detailed explanation of your reasoning for the final diagnosis, addressing points 7a, 7b, and 7c from the instructions above.

Remember to use clear, logical reasoning throughout your analysis. Base your conclusions solely on the provided patient symptoms and lab data, and do not introduce any additional information or assumptions unless explicitly stated in the patient's presentation.
""")


class StructuredDiagnosesModel(BaseModel):
    differential_diagnosis: list[str]
    ruled_out_diagnoses: str
    final_diagnoses: str
    explanation: str
   

structured_llm = StructuredOutputChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o-mini',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4,
    response_schema=StructuredDiagnosesModel
)

# %%
diagnostic_answers, need_reprocess = await async_answer(structured_llm, questions, diagnostic_template, batch_size = 100)
# Out:
# ======
#  processing 1/494 files
#
# ======
#  processing 2/494 files
#
# ======
#  processing 3/494 files
#
# ======
#  processing 4/494 files
#
# ======
#  processing 5/494 files
#
# ======
#  processing 6/494 files
#
# ======
#  processing 7/494 files
#
# ======
#  processing 8/494 files
#
# ======
#  processing 9/494 files
#
# ======
#  processing 10/494 files
#
# ======
#  processing 11/494 files
#
# ======
#  processing 12/494 files
#
# ======
#  processing 13/494 files
#
# ======
#  processing 14/494 files
#
# ======
#  processing 15/494 files
#
# ======
#  processing 16/494 files
#
# ======
#  processing 17/494 files
#
# ======
#  processing 18/494 files
#
# ======
#  processing 19/494 files
#
# ======
#  processing 20/494 files
#
# ======
#  processing 21/494 files
#
# ======
#  processing 22/494 files
#
# ======
#  processing 23/494 files
#
# ======
#  processing 24/494 files
#
# ======
#  processing 25/494 files
#
# ======
#  processing 26/494 files
#
# ======
#  processing 27/494 files
#
# ======
#  processing 28/494 files
#
# ======
#  processing 29/494 files
#
# ======
#  processing 30/494 files
#
# ======
#  processing 31/494 files
#
# ======
#  processing 32/494 files
#
# ======
#  processing 33/494 files
#
# ======
#  processing 34/494 files
#
# ======
#  processing 35/494 files
#
# ======
#  processing 36/494 files
#
# ======
#  processing 37/494 files
#
# ======
#  processing 38/494 files
#
# ======
#  processing 39/494 files
#
# ======
#  processing 40/494 files
#
# ======
#  processing 41/494 files
#
# ======
#  processing 42/494 files
#
# ======
#  processing 43/494 files
#
# ======
#  processing 44/494 files
#
# ======
#  processing 45/494 files
#
# ======
#  processing 46/494 files
#
# ======
#  processing 47/494 files
#
# ======
#  processing 48/494 files
#
# ======
#  processing 49/494 files
#
# ======
#  processing 50/494 files
#
# ======
#  processing 51/494 files
#
# ======
#  processing 52/494 files
#
# ======
#  processing 53/494 files
#
# ======
#  processing 54/494 files
#
# ======
#  processing 55/494 files
#
# ======
#  processing 56/494 files
#
# ======
#  processing 57/494 files
#
# ======
#  processing 58/494 files
#
# ======
#  processing 59/494 files
#
# ======
#  processing 60/494 files
#
# ======
#  processing 61/494 files
#
# ======
#  processing 62/494 files
#
# ======
#  processing 63/494 files
#
# ======
#  processing 64/494 files
#
# ======
#  processing 65/494 files
#
# ======
#  processing 66/494 files
#
# ======
#  processing 67/494 files
#
# ======
#  processing 68/494 files
#
# ======
#  processing 69/494 files
#
# ======
#  processing 70/494 files
#
# ======
#  processing 71/494 files
#
# ======
#  processing 72/494 files
#
# ======
#  processing 73/494 files
#
# ======
#  processing 74/494 files
#
# ======
#  processing 75/494 files
#
# ======
#  processing 76/494 files
#
# ======
#  processing 77/494 files
#
# ======
#  processing 78/494 files
#
# ======
#  processing 79/494 files
#
# ======
#  processing 80/494 files
#
# ======
#  processing 81/494 files
#
# ======
#  processing 82/494 files
#
# ======
#  processing 83/494 files
#
# ======
#  processing 84/494 files
#
# ======
#  processing 85/494 files
#
# ======
#  processing 86/494 files
#
# ======
#  processing 87/494 files
#
# ======
#  processing 88/494 files
#
# ======
#  processing 89/494 files
#
# ======
#  processing 90/494 files
#
# ======
#  processing 91/494 files
#
# ======
#  processing 92/494 files
#
# ======
#  processing 93/494 files
#
# ======
#  processing 94/494 files
#
# ======
#  processing 95/494 files
#
# ======
#  processing 96/494 files
#
# ======
#  processing 97/494 files
#
# ======
#  processing 98/494 files
#
# ======
#  processing 99/494 files
#
# ======
#  processing 100/494 files
#
# ======
#  processing 101/494 files
#
# ======
#  processing 102/494 files
#
# ======
#  processing 103/494 files
#
# ======
#  processing 104/494 files
#
# ======
#  processing 105/494 files
#
# ======
#  processing 106/494 files
#
# ======
#  processing 107/494 files
#
# ======
#  processing 108/494 files
#
# ======
#  processing 109/494 files
#
# ======
#  processing 110/494 files
#
# ======
#  processing 111/494 files
#
# ======
#  processing 112/494 files
#
# ======
#  processing 113/494 files
#
# ======
#  processing 114/494 files
#
# ======
#  processing 115/494 files
#
# ======
#  processing 116/494 files
#
# ======
#  processing 117/494 files
#
# ======
#  processing 118/494 files
#
# ======
#  processing 119/494 files
#
# ======
#  processing 120/494 files
#
# ======
#  processing 121/494 files
#
# ======
#  processing 122/494 files
#
# ======
#  processing 123/494 files
#
# ======
#  processing 124/494 files
#
# ======
#  processing 125/494 files
#
# ======
#  processing 126/494 files
#
# ======
#  processing 127/494 files
#
# ======
#  processing 128/494 files
#
# ======
#  processing 129/494 files
#
# ======
#  processing 130/494 files
#
# ======
#  processing 131/494 files
#
# ======
#  processing 132/494 files
#
# ======
#  processing 133/494 files
#
# ======
#  processing 134/494 files
#
# ======
#  processing 135/494 files
#
# ======
#  processing 136/494 files
#
# ======
#  processing 137/494 files
#
# ======
#  processing 138/494 files
#
# ======
#  processing 139/494 files
#
# ======
#  processing 140/494 files
#
# ======
#  processing 141/494 files
#
# ======
#  processing 142/494 files
#
# ======
#  processing 143/494 files
#
# ======
#  processing 144/494 files
#
# ======
#  processing 145/494 files
#
# ======
#  processing 146/494 files
#
# ======
#  processing 147/494 files
#
# ======
#  processing 148/494 files
#
# ======
#  processing 149/494 files
#
# ======
#  processing 150/494 files
#
# ======
#  processing 151/494 files
#
# ======
#  processing 152/494 files
#
# ======
#  processing 153/494 files
#
# ======
#  processing 154/494 files
#
# ======
#  processing 155/494 files
#
# ======
#  processing 156/494 files
#
# ======
#  processing 157/494 files
#
# ======
#  processing 158/494 files
#
# ======
#  processing 159/494 files
#
# ======
#  processing 160/494 files
#
# ======
#  processing 161/494 files
#
# ======
#  processing 162/494 files
#
# ======
#  processing 163/494 files
#
# ======
#  processing 164/494 files
#
# ======
#  processing 165/494 files
#
# ======
#  processing 166/494 files
#
# ======
#  processing 167/494 files
#
# ======
#  processing 168/494 files
#
# ======
#  processing 169/494 files
#
# ======
#  processing 170/494 files
#
# ======
#  processing 171/494 files
#
# ======
#  processing 172/494 files
#
# ======
#  processing 173/494 files
#
# ======
#  processing 174/494 files
#
# ======
#  processing 175/494 files
#
# ======
#  processing 176/494 files
#
# ======
#  processing 177/494 files
#
# ======
#  processing 178/494 files
#
# ======
#  processing 179/494 files
#
# ======
#  processing 180/494 files
#
# ======
#  processing 181/494 files
#
# ======
#  processing 182/494 files
#
# ======
#  processing 183/494 files
#
# ======
#  processing 184/494 files
#
# ======
#  processing 185/494 files
#
# ======
#  processing 186/494 files
#
# ======
#  processing 187/494 files
#
# ======
#  processing 188/494 files
#
# ======
#  processing 189/494 files
#
# ======
#  processing 190/494 files
#
# ======
#  processing 191/494 files
#
# ======
#  processing 192/494 files
#
# ======
#  processing 193/494 files
#
# ======
#  processing 194/494 files
#
# ======
#  processing 195/494 files
#
# ======
#  processing 196/494 files
#
# ======
#  processing 197/494 files
#
# ======
#  processing 198/494 files
#
# ======
#  processing 199/494 files
#
# ======
#  processing 200/494 files
#
# ======
#  processing 201/494 files
#
# ======
#  processing 202/494 files
#
# ======
#  processing 203/494 files
#
# ======
#  processing 204/494 files
#
# ======
#  processing 205/494 files
#
# ======
#  processing 206/494 files
#
# ======
#  processing 207/494 files
#
# ======
#  processing 208/494 files
#
# ======
#  processing 209/494 files
#
# ======
#  processing 210/494 files
#
# ======
#  processing 211/494 files
#
# ======
#  processing 212/494 files
#
# ======
#  processing 213/494 files
#
# ======
#  processing 214/494 files
#
# ======
#  processing 215/494 files
#
# ======
#  processing 216/494 files
#
# ======
#  processing 217/494 files
#
# ======
#  processing 218/494 files
#
# ======
#  processing 219/494 files
#
# ======
#  processing 220/494 files
#
# ======
#  processing 221/494 files
#
# ======
#  processing 222/494 files
#
# ======
#  processing 223/494 files
#
# ======
#  processing 224/494 files
#
# ======
#  processing 225/494 files
#
# ======
#  processing 226/494 files
#
# ======
#  processing 227/494 files
#
# ======
#  processing 228/494 files
#
# ======
#  processing 229/494 files
#
# ======
#  processing 230/494 files
#
# ======
#  processing 231/494 files
#
# ======
#  processing 232/494 files
#
# ======
#  processing 233/494 files
#
# ======
#  processing 234/494 files
#
# ======
#  processing 235/494 files
#
# ======
#  processing 236/494 files
#
# ======
#  processing 237/494 files
#
# ======
#  processing 238/494 files
#
# ======
#  processing 239/494 files
#
# ======
#  processing 240/494 files
#
# ======
#  processing 241/494 files
#
# ======
#  processing 242/494 files
#
# ======
#  processing 243/494 files
#
# ======
#  processing 244/494 files
#
# ======
#  processing 245/494 files
#
# ======
#  processing 246/494 files
#
# ======
#  processing 247/494 files
#
# ======
#  processing 248/494 files
#
# ======
#  processing 249/494 files
#
# ======
#  processing 250/494 files
#
# ======
#  processing 251/494 files
#
# ======
#  processing 252/494 files
#
# ======
#  processing 253/494 files
#
# ======
#  processing 254/494 files
#
# ======
#  processing 255/494 files
#
# ======
#  processing 256/494 files
#
# ======
#  processing 257/494 files
#
# ======
#  processing 258/494 files
#
# ======
#  processing 259/494 files
#
# ======
#  processing 260/494 files
#
# ======
#  processing 261/494 files
#
# ======
#  processing 262/494 files
#
# ======
#  processing 263/494 files
#
# ======
#  processing 264/494 files
#
# ======
#  processing 265/494 files
#
# ======
#  processing 266/494 files
#
# ======
#  processing 267/494 files
#
# ======
#  processing 268/494 files
#
# ======
#  processing 269/494 files
#
# ======
#  processing 270/494 files
#
# ======
#  processing 271/494 files
#
# ======
#  processing 272/494 files
#
# ======
#  processing 273/494 files
#
# ======
#  processing 274/494 files
#
# ======
#  processing 275/494 files
#
# ======
#  processing 276/494 files
#
# ======
#  processing 277/494 files
#
# ======
#  processing 278/494 files
#
# ======
#  processing 279/494 files
#
# ======
#  processing 280/494 files
#
# ======
#  processing 281/494 files
#
# ======
#  processing 282/494 files
#
# ======
#  processing 283/494 files
#
# ======
#  processing 284/494 files
#
# ======
#  processing 285/494 files
#
# ======
#  processing 286/494 files
#
# ======
#  processing 287/494 files
#
# ======
#  processing 288/494 files
#
# ======
#  processing 289/494 files
#
# ======
#  processing 290/494 files
#
# ======
#  processing 291/494 files
#
# ======
#  processing 292/494 files
#
# ======
#  processing 293/494 files
#
# ======
#  processing 294/494 files
#
# ======
#  processing 295/494 files
#
# ======
#  processing 296/494 files
#
# ======
#  processing 297/494 files
#
# ======
#  processing 298/494 files
#
# ======
#  processing 299/494 files
#
# ======
#  processing 300/494 files
#
# ======
#  processing 301/494 files
#
# ======
#  processing 302/494 files
#
# ======
#  processing 303/494 files
#
# ======
#  processing 304/494 files
#
# ======
#  processing 305/494 files
#
# ======
#  processing 306/494 files
#
# ======
#  processing 307/494 files
#
# ======
#  processing 308/494 files
#
# ======
#  processing 309/494 files
#
# ======
#  processing 310/494 files
#
# ======
#  processing 311/494 files
#
# ======
#  processing 312/494 files
#
# ======
#  processing 313/494 files
#
# ======
#  processing 314/494 files
#
# ======
#  processing 315/494 files
#
# ======
#  processing 316/494 files
#
# ======
#  processing 317/494 files
#
# ======
#  processing 318/494 files
#
# ======
#  processing 319/494 files
#
# ======
#  processing 320/494 files
#
# ======
#  processing 321/494 files
#
# ======
#  processing 322/494 files
#
# ======
#  processing 323/494 files
#
# ======
#  processing 324/494 files
#
# ======
#  processing 325/494 files
#
# ======
#  processing 326/494 files
#
# ======
#  processing 327/494 files
#
# ======
#  processing 328/494 files
#
# ======
#  processing 329/494 files
#
# ======
#  processing 330/494 files
#
# ======
#  processing 331/494 files
#
# ======
#  processing 332/494 files
#
# ======
#  processing 333/494 files
#
# ======
#  processing 334/494 files
#
# ======
#  processing 335/494 files
#
# ======
#  processing 336/494 files
#
# ======
#  processing 337/494 files
#
# ======
#  processing 338/494 files
#
# ======
#  processing 339/494 files
#
# ======
#  processing 340/494 files
#
# ======
#  processing 341/494 files
#
# ======
#  processing 342/494 files
#
# ======
#  processing 343/494 files
#
# ======
#  processing 344/494 files
#
# ======
#  processing 345/494 files
#
# ======
#  processing 346/494 files
#
# ======
#  processing 347/494 files
#
# ======
#  processing 348/494 files
#
# ======
#  processing 349/494 files
#
# ======
#  processing 350/494 files
#
# ======
#  processing 351/494 files
#
# ======
#  processing 352/494 files
#
# ======
#  processing 353/494 files
#
# ======
#  processing 354/494 files
#
# ======
#  processing 355/494 files
#
# ======
#  processing 356/494 files
#
# ======
#  processing 357/494 files
#
# ======
#  processing 358/494 files
#
# ======
#  processing 359/494 files
#
# ======
#  processing 360/494 files
#
# ======
#  processing 361/494 files
#
# ======
#  processing 362/494 files
#
# ======
#  processing 363/494 files
#
# ======
#  processing 364/494 files
#
# ======
#  processing 365/494 files
#
# ======
#  processing 366/494 files
#
# ======
#  processing 367/494 files
#
# ======
#  processing 368/494 files
#
# ======
#  processing 369/494 files
#
# ======
#  processing 370/494 files
#
# ======
#  processing 371/494 files
#
# ======
#  processing 372/494 files
#
# ======
#  processing 373/494 files
#
# ======
#  processing 374/494 files
#
# ======
#  processing 375/494 files
#
# ======
#  processing 376/494 files
#
# ======
#  processing 377/494 files
#
# ======
#  processing 378/494 files
#
# ======
#  processing 379/494 files
#
# ======
#  processing 380/494 files
#
# ======
#  processing 381/494 files
#
# ======
#  processing 382/494 files
#
# ======
#  processing 383/494 files
#
# ======
#  processing 384/494 files
#
# ======
#  processing 385/494 files
#
# ======
#  processing 386/494 files
#
# ======
#  processing 387/494 files
#
# ======
#  processing 388/494 files
#
# ======
#  processing 389/494 files
#
# ======
#  processing 390/494 files
#
# ======
#  processing 391/494 files
#
# ======
#  processing 392/494 files
#
# ======
#  processing 393/494 files
#
# ======
#  processing 394/494 files
#
# ======
#  processing 395/494 files
#
# ======
#  processing 396/494 files
#
# ======
#  processing 397/494 files
#
# ======
#  processing 398/494 files
#
# ======
#  processing 399/494 files
#
# ======
#  processing 400/494 files
#
# ======
#  processing 401/494 files
#
# ======
#  processing 402/494 files
#
# ======
#  processing 403/494 files
#
# ======
#  processing 404/494 files
#
# ======
#  processing 405/494 files
#
# ======
#  processing 406/494 files
#
# ======
#  processing 407/494 files
#
# ======
#  processing 408/494 files
#
# ======
#  processing 409/494 files
#
# ======
#  processing 410/494 files
#
# ======
#  processing 411/494 files
#
# ======
#  processing 412/494 files
#
# ======
#  processing 413/494 files
#
# ======
#  processing 414/494 files
#
# ======
#  processing 415/494 files
#
# ======
#  processing 416/494 files
#
# ======
#  processing 417/494 files
#
# ======
#  processing 418/494 files
#
# ======
#  processing 419/494 files
#
# ======
#  processing 420/494 files
#
# ======
#  processing 421/494 files
#
# ======
#  processing 422/494 files
#
# ======
#  processing 423/494 files
#
# ======
#  processing 424/494 files
#
# ======
#  processing 425/494 files
#
# ======
#  processing 426/494 files
#
# ======
#  processing 427/494 files
#
# ======
#  processing 428/494 files
#
# ======
#  processing 429/494 files
#
# ======
#  processing 430/494 files
#
# ======
#  processing 431/494 files
#
# ======
#  processing 432/494 files
#
# ======
#  processing 433/494 files
#
# ======
#  processing 434/494 files
#
# ======
#  processing 435/494 files
#
# ======
#  processing 436/494 files
#
# ======
#  processing 437/494 files
#
# ======
#  processing 438/494 files
#
# ======
#  processing 439/494 files
#
# ======
#  processing 440/494 files
#
# ======
#  processing 441/494 files
#
# ======
#  processing 442/494 files
#
# ======
#  processing 443/494 files
#
# ======
#  processing 444/494 files
#
# ======
#  processing 445/494 files
#
# ======
#  processing 446/494 files
#
# ======
#  processing 447/494 files
#
# ======
#  processing 448/494 files
#
# ======
#  processing 449/494 files
#
# ======
#  processing 450/494 files
#
# ======
#  processing 451/494 files
#
# ======
#  processing 452/494 files
#
# ======
#  processing 453/494 files
#
# ======
#  processing 454/494 files
#
# ======
#  processing 455/494 files
#
# ======
#  processing 456/494 files
#
# ======
#  processing 457/494 files
#
# ======
#  processing 458/494 files
#
# ======
#  processing 459/494 files
#
# ======
#  processing 460/494 files
#
# ======
#  processing 461/494 files
#
# ======
#  processing 462/494 files
#
# ======
#  processing 463/494 files
#
# ======
#  processing 464/494 files
#
# ======
#  processing 465/494 files
#
# ======
#  processing 466/494 files
#
# ======
#  processing 467/494 files
#
# ======
#  processing 468/494 files
#
# ======
#  processing 469/494 files
#
# ======
#  processing 470/494 files
#
# ======
#  processing 471/494 files
#
# ======
#  processing 472/494 files
#
# ======
#  processing 473/494 files
#
# ======
#  processing 474/494 files
#
# ======
#  processing 475/494 files
#
# ======
#  processing 476/494 files
#
# ======
#  processing 477/494 files
#
# ======
#  processing 478/494 files
#
# ======
#  processing 479/494 files
#
# ======
#  processing 480/494 files
#
# ======
#  processing 481/494 files
#
# ======
#  processing 482/494 files
#
# ======
#  processing 483/494 files
#
# ======
#  processing 484/494 files
#
# ======
#  processing 485/494 files
#
# ======
#  processing 486/494 files
#
# ======
#  processing 487/494 files
#
# ======
#  processing 488/494 files
#
# ======
#  processing 489/494 files
#
# ======
#  processing 490/494 files
#
# ======
#  processing 491/494 files
#
# ======
#  processing 492/494 files
#
# ======
#  processing 493/494 files
#
# ======
#  processing 494/494 files
#
# processing batch 0 of size 100
# processing batch 1 of size 100
# processing batch 2 of size 100
# processing batch 3 of size 100
# processing batch 4 of size 100

# %%
eval_responses(gpt_4_responses, 'answer', [ob['final_diagnoses'] for ob in diagnostic_answers])
# Out:
# # correct = 125 / 494
# 0.25303643724696356

# %%
gpt_4_responses.head()
# Out:
#                                             question  \
# 0  Two weeks after undergoing an emergency cardia...
# 1  A 46-year-old man is brought to the emergency ...
# 2  A 30-year-old African American woman comes to ...
# 3  A 67-year-old man who was diagnosed with arthr...
# 4  A one-day-old male is evaluated in the hospita...
#
#                              answer                              CoT.2  \
# 0          Cholesterol embolization  Cholesterol embolization syndrome
# 1       Benzodiazepine intoxication               Alcoholic neuropathy
# 2  Histoplasma capsulatum infection                     Histoplasmosis
# 3               Psoriatic arthritis                Psoriatic Arthritis
# 4                  Duodenal atresia                   Duodenal atresia
#
#                                            Rationale CoT Grade  \
# 0  This patient's presentation of decreased urina...         Y
# 1  This patient presents with altered mental stat...         N
# 2  This patient has recently been hiking in Missi...         Y
# 3  This patient has a long history of arthritis a...         Y
# 4  The baby in question is displaying signs of in...         Y
#
#                                   DR  \
# 0  Cholesterol embolization syndrome
# 1                 Cerebellar disease
# 2                     Histoplasmosis
# 3                Psoriatic Arthritis
# 4                   Duodenal atresia
#
#                                          Rationale.1 DR Grade.1  \
# 0  The differential for this patient includes acu...          Y
# 1  The differential for this patient includes alc...          N
# 2  The differential diagnosis in this case includ...          Y
# 3  The differential diagnosis for this patient in...          Y
# 4  This neonate presents with bilious vomiting, a...          Y
#
#                             IR  \
# 0  Atheroembolic renal disease
# 1    Wernicke's encephalopathy
# 2               Histoplasmosis
# 3          Psoriatic Arthritis
# 4               Meconium ileus
#
#                                          Rationale.2 IR Grade.1  \
# 0  This patient has decreased urinary output, mal...          Y
# 1  This patient's symptoms of altered mental stat...          N
# 2  This patient presents with fever, cough, chest...          Y
# 3  The patient's clinical presentation suggests p...          Y
# 4  This neonate's clinical presentation of biliou...          N
#
#                           AR  \
# 0       Cholesterol embolism
# 1  Wernicke's encephalopathy
# 2             Histoplasmosis
# 3        Psoriatic Arthritis
# 4         Intestinal atresia
#
#                                          Rationale.3 AR Grade.1  \
# 0  The patient's recent history of cardiac cathet...          Y
# 1  The patient's symptoms (somnolence, slurred sp...          N
# 2  The patient's history of recent hiking in Miss...          Y
# 3  The patient presents with several features sug...          Y
# 4  The symptoms presented by this neonate, such a...          Y
#
#                                   BR  \
# 0       Contrast-induced nephropathy
# 1          Wernicke's encephalopathy
# 2             Histoplasma capsulatum
# 3                Psoriatic Arthritis
# 4  Duodenal atresia in Down Syndrome
#
#                                          Rationale.4 BR Grade.1
# 0  This patient's symptoms and clinical history s...          N
# 1  The prior probability of Wernicke's encephalop...          N
# 2  The prior probability of Histoplasmosis (a fun...          Y
# 3  The prior probability of psoriatic arthritis i...          Y
# 4  In Bayesian reasoning, we begin with a prior p...          Y

# %%
diagnostic_answers[0]
# Out:
# {'differential_diagnosis': ['Renal artery thrombosis',
#   'Acute glomerulonephritis',
#   'Acute kidney injury (AKI) secondary to dehydration or nephrotoxicity',
#   'Eosinophilic vasculitis',
#   'Drug-induced acute interstitial nephritis'],
#  'ruled_out_diagnoses': 'Renal artery thrombosis ruled out due to absence of flank pain and lack of signs of acute embolic events. Eosinophilic vasculitis not supported as no significant systemic symptoms or prior indications of allergy were mentioned, despite eosinophilia.',
#  'final_diagnoses': 'Acute kidney injury (AKI) secondary to nephrotoxicity and possibly related to use of naproxen and/or other cardiac medications.',
#  'explanation': 'The patient exhibits decreased urinary output, malaise, and significant elevation of serum creatinine, indicating renal impairment. The presence of fever and leukocytosis may suggest an inflammatory response or infection, possibly due to recent catheterization. The renal biopsy showing intravascular spindle-shaped vacuoles is suggestive of drug-induced nephrotoxicity commonly associated with medications such as NSAIDs and antifungal agents rather than glomerulonephritis. Other diagnoses, such as acute glomerulonephritis, are less likely due to the type of renal findings and the specific lab results indicating renal damage without classic signs of GN. Overall, AKI due to nephrotoxic effects of recent medications, particularly naproxen in a patient with predisposing diabetes and cardiovascular disease, aligns with the clinical picture. Further confirmation could be achieved through monitoring serum electrolytes, urinalysis, and possibly imaging to rule out obstructive causes.'}

# %%
diagnostic_answers[3]
# Out:
# {'differential_diagnosis': ['Psoriatic arthritis - A type of inflammatory arthritis associated with psoriasis that can cause joint pain and swelling, commonly leading to nail changes such as pitting, which the patient exhibits.',
#   "Rheumatoid arthritis - An autoimmune condition characterized by symmetric joint involvement. However, the patient's significant improvement with rest and the nature of joint involvement makes this less likely.",
#   "Osteoarthritis - Degenerative joint disease usually presents with chronic pain and is commonly seen in older adults. In this case, the patient's symptoms were acute and involved swelling and pitting nails, making this a less likely diagnosis.",
#   'Gout - A type of arthritis characterized by sudden severe pain and swelling, typically affecting one joint at a time. The bilateral joint involvement and pitting of the nails are not characteristic of gout.'],
#  'ruled_out_diagnoses': "Rheumatoid arthritis was ruled out because the patient's symptoms improve with rest, which is uncommon for this condition. Osteoarthritis was considered but ruled out due to the acute nature of swelling and the presence of dactylitis (pitting in nails). Gout was ruled out as well given the bilateral pattern of joint involvement rather than acute attacks.",
#  'final_diagnoses': 'Psoriatic arthritis',
#  'explanation': "The patient's presentation suggests psoriatic arthritis as the most likely diagnosis. This condition explains the bilateral knee swelling and pain, improvement of symptoms with rest, along with the presence of nail changes (pitting) and scalp symptoms (dandruff) which are common in psoriasis. It fits with the patient's demographic of being 67 years old and male. The bilateral nature of joint involvement and non-unilateral presentation aligns more closely with psoriatic arthritis rather than other forms like rheumatoid arthritis which typically worsens with rest. To further confirm this diagnosis, tests such as imaging studies (X-ray) looking for joint erosions or MRI for soft tissue abnormalities, as well as lab tests for inflammatory markers (ESR, CRP) or HLA-B27 can be helpful."}

# %%
class EvalAnswer(BaseModel):
    reasoning: str
    answer: bool


eval_llm = StructuredOutputChatOpenAI(
    base_url='https://api.openai.com/v1',
    model = 'gpt-4o-mini',
    temperature= 1,
    api_key = os.environ.get('OPENAI_API_KEY'),
    max_retries = 4,
    response_schema=EvalAnswer
)

# %%
eval_prompt_template = PromptTemplate("""
You are an expert medical grader who specializes in grading whether a diagnoses is correct or not.

If the correct diagnoses is {correct_answer}, could a diagnoses of {predicted_answer} also be considered correct?

provide a brief explanation and an answer that is TRUE or FALSE. TRUE means that the other diagnoses would be considered correct and functionally the same as the "correct" diagnoses.
""")


another_template = PromptTemplate("""
You are a medical AI assistant tasked with determining whether two given medical diagnoses are essentially the same or different. Your goal is to compare the diagnoses and decide if they refer to the same medical condition, even if they might use slightly different terminology.

Here are the two diagnoses you need to compare:

diagnoses1 = {correct_answer}
                                  
diagnoses2 = {predicted_answer}

Compare these two diagnoses carefully. Consider the following aspects:
1. The main condition or disease mentioned
2. Any specific subtypes or variations
3. The affected body part or system
4. Any mentioned symptoms or characteristics
5. The severity or stage of the condition (if specified)

Provide your reasoning and decision in the following format:
1. First, explain your thought process and analysis inside "reasoning" field.
2. Then, give your final decision as either True or False inside the "answer". Answer True if the diagnoses are the SAME or False if they are DIFFERENT.

Guidelines for comparison:
- Diagnoses should be considered the same if they refer to the same underlying condition, even if the exact wording is different.
- Minor differences in terminology (e.g., "heart attack" vs. "myocardial infarction") should not necessarily be considered different diagnoses.
- However, specific subtypes or variations of a condition should be considered different (e.g., "Type 1 diabetes" vs. "Type 2 diabetes").
- If one diagnosis is more specific than the other but still refers to the same general condition, they should be considered the same. (eg "Type 1 diabetes" and "diabetes")

Here are some examples:
- "Acute myocardial infarction" and "Heart attack" would be considered the SAME.
- "Bronchitis" and "Pneumonia" would be considered DIFFERENT.
- "Migraine with aura" and "Migraine without aura" would be considered DIFFERENT.
- "Osteoarthritis of the knee" and "Degenerative joint disease of the knee" would be considered the SAME.

Remember to consider all aspects of the diagnoses before making your decision. If you're unsure, explain your uncertainty in the reasoning section.

Begin your analysis now.
""")

async def llm_eval_responses(response_df: pd.DataFrame, eval_llm: ChatLLM, true_col:str, pred_col: str):
    '''
    Given a dataframe of responses, a true column label that is in the dataframe and an array of
    responses from the llm

    ex: question: What color is the sky? answer = blue, llm_res = "the sky is blue" would evaluate to True
    '''
    no_nulls = response_df[~response_df[true_col].isna()].reset_index()

    filled = [eval_prompt_template.populate(correct_answer = correct_answer, predicted_answer = predicted_answer) for (correct_answer, predicted_answer) in no_nulls[[true_col, pred_col]].values ]
    
    is_correct_answers = await asyncio.gather(*[ async_answer_from_question(eval_llm, p) for p in filled])

    answer_is_correct = []
    for is_correct in is_correct_answers:
        parsed = json.loads(is_correct.content)
        answer_is_correct.append(parsed['answer'])

    correct = pd.Series(answer_is_correct)
    print(f'# correct = {correct.sum()} / {len(correct)}')

    return correct.sum() / len(correct), correct

# %%
r, correct = await llm_eval_responses(gpt_4_responses, eval_llm, 'answer', 'DR')
# Out:
# # correct = 96 / 494

# %% [markdown]
# UFF dah This is not trivial

# %%
correct
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 489    False
# 490     True
# 491    False
# 492    False
# 493    False
# Length: 494, dtype: bool
